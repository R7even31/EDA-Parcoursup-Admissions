# %% [markdown]
# # Préparation des données Parcoursup en gardant les coordonnées
#
# Ce bloc prépare une base propre avant l'analyse uni-dimensionnelle :
# - chargement des données,
# - sélection des variables utiles,
# - création d'indicateurs simples et interprétables pour l'analyse.

# %%
library(tidyverse)

# lecture du CSV Parcoursup (sep=';' car format français, check.names pour noms exploitables en R)
data <- read.csv('Parcoursup.csv', sep = ';', header = TRUE, stringsAsFactors = TRUE, check.names = TRUE)

# Contrôle minimal : nombre de lignes/colonnes + aperçu de 3 lignes
dim(data)
head(data, 3)
# Out:
# Warning message:
# "le package 'tidyverse' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'ggplot2' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'tibble' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'tidyr' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'readr' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'purrr' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'dplyr' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'stringr' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'forcats' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'lubridate' a été compilé avec la version R 4.4.3"
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.6
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.2     ✔ tibble    3.3.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.2
# ✔ purrr     1.2.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# [1] 14252   118
#   Session Statut.de.l.établissement.de.la.filière.de.formation..public..privé..
# 1 2025    Public
# 2 2025    Public
# 3 2025    Public
#   Code.UAI.de.l.établissement
# 1 0692185A
# 2 0931827F
# 3 0421573G
#   Établissement
# 1 INSTITUT DES SCIENCES ET TECHNIQUES DE LA READAPTATION UNIVERSITE LYON 1
# 2 Université Paris 8
# 3 IFSI du CH de Roanne
#   Code.départemental.de.l.établissement Département.de.l.établissement
# 1 69                                    Rhône
# 2 93                                    Seine-Saint-Denis
# 3 42                                    Loire
#   Région.de.l.établissement Académie.de.l.établissement
# 1 Auvergne-Rhône-Alpes      Lyon
# 2 Ile-de-France             Créteil
# 3 Auvergne-Rhône-Alpes      Lyon
#   Commune.de.l.établissement
# 1 Lyon 8e  Arrondissement
# 2 Saint-Denis
# 3 Roanne
#   Filière.de.formation                                                 ⋯
# 1 Certificat de capacité d'Orthoptiste                                 ⋯
# 2 Licence - Langues étrangères appliquées - Parcours Anglais / Italien ⋯
# 3 D.E Infirmier                                                        ⋯
#   tri                 cod_aff_form
# 1 3_Autres formations 28087
# 2 1_universités       28100
# 3 3_Autres formations 28144
#   Concours.communs.et.banque.d.épreuves
# 1 Aix-Marseille Université - Site de Marseille Timone
# 2
# 3
#   Lien.de.la.formation.sur.la.plateforme.Parcoursup
# 1 https://dossierappel.parcoursup.fr/Candidats/public/fiches/afficherFicheFormation?g_ta_cod=28087&typeBac=0&originePc=0
# 2 https://dossierappel.parcoursup.fr/Candidats/public/fiches/afficherFicheFormation?g_ta_cod=28100&typeBac=0&originePc=0
# 3 https://dossierappel.parcoursup.fr/Candidats/public/fiches/afficherFicheFormation?g_ta_cod=28144&typeBac=0&originePc=0
#   Taux.d.accès
# 1 13
# 2 98
# 3 40
#   Part.des.terminales.générales.qui.étaient.en.position.de.recevoir.une.proposition.en.phase.principale
# 1 93
# 2 57
# 3 56
#   Part.des.terminales.technologiques.qui.étaient.en.position.de.recevoir.une.proposition.en.phase.principale
# 1 7
# 2 24
# 3 37
#   Part.des.terminales.professionnelles.qui.étaient.en.position.de.recevoir.une.proposition.en.phase.principale
# 1 1
# 2 19
# 3 7
#   etablissement_id_paysage composante_id_paysage
# 1 NA                       NA
# 2 NA                       NA
# 3 NA                       NA

# %% [markdown]
# ## Vérification rapide
#
# On vérifie la structure globale sans multiplier les diagnostics : dimensions, types et quelques statistiques de base.

# %%
# Vue d'ensemble des types de variables (numériques, caractères, etc.)
glimpse(data)

# Résumé ciblé sur des variables de volume utiles pour la suite
summary(select(data,
  Capacité.de.l.établissement.par.formation,
  Effectif.total.des.candidats.pour.une.formation,
  Effectif.total.des.candidats.ayant.accepté.la.proposition.de.l.établissement..admis.
))
# Out:
# Rows: 14,252
# Columns: 118
# $ Session                                                                                                                                          <int> …
# $ Statut.de.l.établissement.de.la.filière.de.formation..public..privé..                                                                            <fct> …
# $ Code.UAI.de.l.établissement                                                                                                                      <fct> …
# $ Établissement                                                                                                                                    <fct> …
# $ Code.départemental.de.l.établissement                                                                                                            <fct> …
# $ Département.de.l.établissement                                                                                                                   <fct> …
# $ Région.de.l.établissement                                                                                                                        <fct> …
# $ Académie.de.l.établissement                                                                                                                      <fct> …
# $ Commune.de.l.établissement                                                                                                                       <fct> …
# $ Filière.de.formation                                                                                                                             <fct> …
# $ Sélectivité                                                                                                                                      <fct> …
# $ Filière.de.formation.très.agrégée                                                                                                                <fct> …
# $ Filière.de.formation.détaillée                                                                                                                   <fct> …
# $ Filière.de.formation.1                                                                                                                           <fct> …
# $ Filière.de.formation.détaillée.bis                                                                                                               <fct> …
# $ Filière.de.formation.très.détaillée                                                                                                              <fct> …
# $ Coordonnées.GPS.de.la.formation                                                                                                                  <fct> …
# $ Capacité.de.l.établissement.par.formation                                                                                                        <int> …
# $ Effectif.total.des.candidats.pour.une.formation                                                                                                  <int> …
# $ Dont.effectif.des.candidates.pour.une.formation                                                                                                  <int> …
# $ Effectif.total.des.candidats.en.phase.principale                                                                                                 <int> …
# $ Dont.effectif.des.candidats.ayant.postulé.en.internat                                                                                            <int> …
# $ Effectif.des.candidats.néo.bacheliers.généraux.en.phase.principale                                                                               <int> …
# $ Dont.effectif.des.candidats.boursiers.néo.bacheliers.généraux.en.phase.principale                                                                <int> …
# $ Effectif.des.candidats.néo.bacheliers.technologiques.en.phase.principale                                                                         <int> …
# $ Dont.effectif.des.candidats.boursiers.néo.bacheliers.technologiques.en.phase.principale                                                          <int> …
# $ Effectif.des.candidats.néo.bacheliers.professionnels.en.phase.principale                                                                         <int> …
# $ Dont.effectif.des.candidats.boursiers.néo.bacheliers.professionnels.en.phase.principale                                                          <int> …
# $ Effectif.des.autres.candidats.en.phase.principale                                                                                                <int> …
# $ Effectif.total.des.candidats.en.phase.complémentaire                                                                                             <int> …
# $ Effectif.des.candidats.néo.bacheliers.généraux.en.phase.complémentaire                                                                           <int> …
# $ Effectif.des.candidats.néo.bacheliers.technologique.en.phase.complémentaire                                                                      <int> …
# $ Effectif.des.candidats.néo.bacheliers.professionnels.en.phase.complémentaire                                                                     <int> …
# $ Effectifs.des.autres.candidats.en.phase.complémentaire                                                                                           <int> …
# $ Effectif.total.des.candidats.classés.par.l.établissement.en.phase.principale                                                                     <int> …
# $ Effectif.des.candidats.classés.par.l.établissement.en.phase.complémentaire                                                                       <int> …
# $ Effectif.des.candidats.classés.par.l.établissement.en.internat..CPGE.                                                                            <int> …
# $ Effectif.des.candidats.classés.par.l.établissement.hors.internat..CPGE.                                                                          <int> …
# $ Effectif.des.candidats.néo.bacheliers.généraux.classés.par.l.établissement                                                                       <int> …
# $ Dont.effectif.des.candidats.boursiers.néo.bacheliers.généraux.classés.par.l.établissement                                                        <int> …
# $ Effectif.des.candidats.néo.bacheliers.technologiques.classés.par.l.établissement                                                                 <int> …
# $ Dont.effectif.des.candidats.boursiers.néo.bacheliers.technologiques.classés.par.l.établissement                                                  <int> …
# $ Effectif.des.candidats.néo.bacheliers.professionnels.classés.par.l.établissement                                                                 <int> …
# $ Dont.effectif.des.candidats.boursiers.néo.bacheliers.professionnels.classés.par.l.établissement                                                  <int> …
# $ Effectif.des.autres.candidats.classés.par.l.établissement                                                                                        <int> …
# $ Effectif.total.des.candidats.ayant.reçu.une.proposition.d.admission.de.la.part.de.l.établissement                                                <int> …
# $ Effectif.total.des.candidats.ayant.accepté.la.proposition.de.l.établissement..admis.                                                             <int> …
# $ Dont.effectif.des.candidates.admises                                                                                                             <int> …
# $ Effectif.des.admis.en.phase.principale                                                                                                           <int> …
# $ Effectif.des.admis.en.phase.complémentaire                                                                                                       <int> …
# $ Dont.effectif.des.admis.ayant.reçu.leur.proposition.d.admission.à.l.ouverture.de.la.procédure.principale                                         <int> …
# $ Dont.effectif.des.admis.ayant.reçu.leur.proposition.d.admission.avant.le.baccalauréat                                                            <int> …
# $ Dont.effectif.des.admis.ayant.reçu.leur.proposition.d.admission.avant.la.fin.de.la.procédure.principale                                          <int> …
# $ Dont.effectif.des.admis.en.internat                                                                                                              <int> …
# $ Dont.effectif.des.admis.boursiers.néo.bacheliers                                                                                                 <int> …
# $ Effectif.des.admis.néo.bacheliers                                                                                                                <int> …
# $ Effectif.des.admis.néo.bacheliers.généraux                                                                                                       <int> …
# $ Effectif.des.admis.néo.bacheliers.technologiques                                                                                                 <int> …
# $ Effectif.des.admis.néo.bacheliers.professionnels                                                                                                 <int> …
# $ Effectif.des.autres.candidats.admis                                                                                                              <int> …
# $ Dont.effectif.des.admis.néo.bacheliers.sans.information.sur.la.mention.au.bac                                                                    <int> …
# $ Dont.effectif.des.admis.néo.bacheliers.sans.mention.au.bac                                                                                       <int> …
# $ Dont.effectif.des.admis.néo.bacheliers.avec.mention.Assez.Bien.au.bac                                                                            <int> …
# $ Dont.effectif.des.admis.néo.bacheliers.avec.mention.Bien.au.bac                                                                                  <int> …
# $ Dont.effectif.des.admis.néo.bacheliers.avec.mention.Très.Bien.au.bac                                                                             <int> …
# $ Dont.effectif.des.admis.néo.bacheliers.avec.mention.Très.Bien.avec.félicitations.au.bac                                                          <int> …
# $ Effectif.des.admis.néo.bacheliers.généraux.ayant.eu.une.mention.au.bac                                                                           <int> …
# $ Effectif.des.admis.néo.bacheliers.technologiques.ayant.eu.une.mention.au.bac                                                                     <int> …
# $ Effectif.des.admis.néo.bacheliers.professionnels.ayant.eu.une.mention.au.bac                                                                     <int> …
# $ Dont.effectif.des.admis.issus.du.même.établissement..BTS.CPGE.                                                                                   <int> …
# $ Dont.effectif.des.admises.issues.du.même.établissement..BTS.CPGE.                                                                                <int> …
# $ Dont.effectif.des.admis.issus.de.la.même.académie                                                                                                <int> …
# $ Dont.effectif.des.admis.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies.                                                             <int> …
# $ X..d.admis.ayant.reçu.leur.proposition.d.admission.à.l.ouverture.de.la.procédure.principale                                                      <dbl> …
# $ X..d.admis.ayant.reçu.leur.proposition.d.admission.avant.le.baccalauréat                                                                         <dbl> …
# $ X..d.admis.ayant.reçu.leur.proposition.d.admission.avant.la.fin.de.la.procédure.principale                                                       <dbl> …
# $ X..d.admis.dont.filles                                                                                                                           <dbl> …
# $ X..d.admis.néo.bacheliers.issus.de.la.même.académie                                                                                              <dbl> …
# $ X..d.admis.néo.bacheliers.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies.                                                           <dbl> …
# $ X..d.admis.néo.bacheliers.issus.du.même.établissement..BTS.CPGE.                                                                                 <dbl> …
# $ X..d.admis.néo.bacheliers.boursiers                                                                                                              <dbl> …
# $ X..d.admis.néo.bacheliers                                                                                                                        <dbl> …
# $ X..d.admis.néo.bacheliers.sans.information.sur.la.mention.au.bac                                                                                 <dbl> …
# $ X..d.admis.néo.bacheliers.sans.mention.au.bac                                                                                                    <dbl> …
# $ X..d.admis.néo.bacheliers.avec.mention.Assez.Bien.au.bac                                                                                         <dbl> …
# $ X..d.admis.néo.bacheliers.avec.mention.Bien.au.bac                                                                                               <dbl> …
# $ X..d.admis.néo.bacheliers.avec.mention.Très.Bien.au.bac                                                                                          <dbl> …
# $ X..d.admis.néo.bacheliers.avec.mention.Très.Bien.avec.félicitations.au.bac                                                                       <dbl> …
# $ X..d.admis.néo.bacheliers.généraux                                                                                                               <dbl> …
# $ Dont...d.admis.avec.mention..BG.                                                                                                                 <dbl> …
# $ X..d.admis.néo.bacheliers.technologiques                                                                                                         <dbl> …
# $ Dont...d.admis.avec.mention..BT.                                                                                                                 <dbl> …
# $ X..d.admis.néo.bacheliers.professionnels                                                                                                         <dbl> …
# $ Dont...d.admis.avec.mention..BP.                                                                                                                 <dbl> …
# $ Effectif.des.candidats.en.terminale.générale.ayant.reçu.une.proposition.d.admission.de.la.part.de.l.établissement                                <dbl> …
# $ Dont.effectif.des.candidats.boursiers.en.terminale.générale.ayant.reçu.une.proposition.d.admission.de.la.part.de.l.établissement                 <dbl> …
# $ Effectif.des.candidats.en.terminale.technologique.ayant.reçu.une.proposition.d.admission.de.la.part.de.l.établissement                           <dbl> …
# $ Dont.effectif.des.candidats.boursiers.en.terminale.technologique.ayant.reçu.une.proposition.d.admission.de.la.part.de.l.établissement            <dbl> …
# $ Effectif.des.candidats.en.terminale.professionnelle.ayant.reçu.une.proposition.d.admission.de.la.part.de.l.établissement                         <dbl> …
# $ Dont.effectif.des.candidats.boursiers.en.terminale.générale.professionnelle.ayant.reçu.une.proposition.d.admission.de.la.part.de.l.établissement <dbl> …
# $ Effectif.des.autres.candidats.ayant.reçu.une.proposition.d.admission.de.la.part.de.l.établissement                                               <dbl> …
# $ Regroupement.1.effectué.par.les.formations.pour.les.classements                                                                                  <fct> …
# $ Rang.du.dernier.appelé.du.groupe.1                                                                                                               <fct> …
# $ Regroupement.2.effectué.par.les.formations.pour.les.classements                                                                                  <fct> …
# $ Rang.du.dernier.appelé.du.groupe.2                                                                                                               <int> …
# $ Regroupement.3.effectué.par.les.formations.pour.les.classements                                                                                  <fct> …
# $ Rang.du.dernier.appelé.du.groupe.3                                                                                                               <int> …
# $ list_com                                                                                                                                         <fct> …
# $ tri                                                                                                                                              <fct> …
# $ cod_aff_form                                                                                                                                     <int> …
# $ Concours.communs.et.banque.d.épreuves                                                                                                            <fct> …
# $ Lien.de.la.formation.sur.la.plateforme.Parcoursup                                                                                                <fct> …
# $ Taux.d.accès                                                                                                                                     <fct> …
# $ Part.des.terminales.générales.qui.étaient.en.position.de.recevoir.une.proposition.en.phase.principale                                            <fct> …
# $ Part.des.terminales.technologiques.qui.étaient.en.position.de.recevoir.une.proposition.en.phase.principale                                       <fct> …
# $ Part.des.terminales.professionnelles.qui.étaient.en.position.de.recevoir.une.proposition.en.phase.principale                                     <fct> …
# $ etablissement_id_paysage                                                                                                                         <lgl> …
# $ composante_id_paysage                                                                                                                            <lgl> …
#  Capacité.de.l.établissement.par.formation
#  Min.   :   0.00
#  1st Qu.:  18.00
#  Median :  30.00
#  Mean   :  53.98
#  3rd Qu.:  50.00
#  Max.   :3400.00
#  Effectif.total.des.candidats.pour.une.formation
#  Min.   :    1.0
#  1st Qu.:  160.0
#  Median :  385.0
#  Mean   :  947.4
#  3rd Qu.: 1016.0
#  Max.   :19404.0
#  Effectif.total.des.candidats.ayant.accepté.la.proposition.de.l.établissement..admis.
#  Min.   :   0.00
#  1st Qu.:  14.00
#  Median :  25.00
#  Mean   :  46.36
#  3rd Qu.:  46.00
#  Max.   :2187.00

# %% [markdown]
# ## Nettoyage et variables construites
#
# Logique du nettoyage :
# - retirer les colonnes techniques ou trop fines pour l'objectif (identifiants, GPS, liens, détails redondants),
# - conserver les colonnes utiles à l'analyse genre/sélectivité/profil des admis,
# - construire des variables agrégées simples (2 phases, pourcentages de genre, parts de mentions).

# %%
# Colonnes retirées : identifiants techniques, géographie trop fine, détails redondants
cols_to_drop <- c(
  'Session',
  'Code.UAI.de.l.établissement',
  'Code.départemental.de.l.établissement',
  'Département.de.l.établissement',
  'Commune.de.l.établissement',
  'Filière.de.formation.détaillée',
  'Filière.de.formation.détaillée.bis',
  'Filière.de.formation.très.détaillée',
  'Dont.effectif.des.candidats.ayant.postulé.en.internat',
  'Effectif.total.des.candidats.classés.par.l.établissement.en.phase.principale',
  'Effectif.des.candidats.classés.par.l.établissement.en.phase.complémentaire',
  'Effectif.des.candidats.classés.par.l.établissement.en.internat..CPGE.',
  'Effectif.des.candidats.classés.par.l.établissement.hors.internat..CPGE.',
  'Concours.communs.et.banque.d.épreuves',
  'cod_aff_form',
  'Lien.de.la.formation.sur.la.plateforme.Parcoursup',
  'etablissement_id_paysage',
  'composante_id_paysage'
)

# any_of : évite une erreur si une colonne listée est absente
data <- data %>%
  select(-any_of(cols_to_drop))

# Colonnes converties en numérique avant calcul de ratios
num_cols <- c(
  'Capacité.de.l.établissement.par.formation',
  'Effectif.total.des.candidats.en.phase.principale',
  'Effectif.total.des.candidats.en.phase.complémentaire',
  'Effectif.des.admis.en.phase.principale',
  'Effectif.des.admis.en.phase.complémentaire',
  'Effectif.total.des.candidats.ayant.accepté.la.proposition.de.l.établissement..admis.',
  'Dont.effectif.des.candidates.admises',
  'Effectif.des.admis.néo.bacheliers',
  'Dont.effectif.des.admis.néo.bacheliers.sans.mention.au.bac',
  'Dont.effectif.des.admis.néo.bacheliers.avec.mention.Assez.Bien.au.bac',
  'Dont.effectif.des.admis.néo.bacheliers.avec.mention.Bien.au.bac',
  'Dont.effectif.des.admis.néo.bacheliers.avec.mention.Très.Bien.au.bac',
  'Dont.effectif.des.admis.néo.bacheliers.avec.mention.Très.Bien.avec.félicitations.au.bac'
)

data <- data %>%
  # across(...): applique as.numeric à toutes les colonnes de num_cols
  mutate(across(any_of(num_cols), ~ suppressWarnings(as.numeric(.x)))) %>%
  mutate(
    # Agrégation des volumes sur les deux phases d'admission
    Effectif.total.candidats.2phases = coalesce(Effectif.total.des.candidats.en.phase.principale, 0) +
      coalesce(Effectif.total.des.candidats.en.phase.complémentaire, 0),
    Effectif.total.admis.2phases = coalesce(Effectif.des.admis.en.phase.principale, 0) +
      coalesce(Effectif.des.admis.en.phase.complémentaire, 0),
      #coalesce remplace les valeurs manquantes par 0

    # Parts filles/garçons parmi les admis (entre 0 et 1)
    pct_filles_admises = if_else(
      Effectif.total.des.candidats.ayant.accepté.la.proposition.de.l.établissement..admis. > 0,
      Dont.effectif.des.candidates.admises / Effectif.total.des.candidats.ayant.accepté.la.proposition.de.l.établissement..admis.,
      NA_real_
    ),
    pct_garcons_admis = if_else(!is.na(pct_filles_admises), 1 - pct_filles_admises, NA_real_),

    # Parts de mentions parmi les admis néo-bacheliers
    part_mention_ab = if_else(Effectif.des.admis.néo.bacheliers > 0,
      Dont.effectif.des.admis.néo.bacheliers.avec.mention.Assez.Bien.au.bac / Effectif.des.admis.néo.bacheliers, NA_real_),
    part_mention_b = if_else(Effectif.des.admis.néo.bacheliers > 0,
      Dont.effectif.des.admis.néo.bacheliers.avec.mention.Bien.au.bac / Effectif.des.admis.néo.bacheliers, NA_real_),
    part_mention_tb = if_else(Effectif.des.admis.néo.bacheliers > 0,
      Dont.effectif.des.admis.néo.bacheliers.avec.mention.Très.Bien.au.bac / Effectif.des.admis.néo.bacheliers, NA_real_),
    part_mention_tb_fel = if_else(Effectif.des.admis.néo.bacheliers > 0,
      Dont.effectif.des.admis.néo.bacheliers.avec.mention.Très.Bien.avec.félicitations.au.bac / Effectif.des.admis.néo.bacheliers, NA_real_)
  )

# %%
head(data)
# Out:
#   Statut.de.l.établissement.de.la.filière.de.formation..public..privé..
# 1 Public
# 2 Public
# 3 Public
# 4 Public
# 5 Public
# 6 Public
#   Établissement
# 1 INSTITUT DES SCIENCES ET TECHNIQUES DE LA READAPTATION UNIVERSITE LYON 1
# 2 Université Paris 8
# 3 IFSI du CH de Roanne
# 4 Université Claude Bernard Lyon 1
# 5 Université Claude Bernard Lyon 1
# 6 Université de Bordeaux - Antenne d'Agen
#   Région.de.l.établissement Académie.de.l.établissement
# 1 Auvergne-Rhône-Alpes      Lyon
# 2 Ile-de-France             Créteil
# 3 Auvergne-Rhône-Alpes      Lyon
# 4 Auvergne-Rhône-Alpes      Lyon
# 5 Auvergne-Rhône-Alpes      Lyon
# 6 Nouvelle Aquitaine        Bordeaux
#   Filière.de.formation
# 1 Certificat de capacité d'Orthoptiste
# 2 Licence - Langues étrangères appliquées - Parcours Anglais / Italien
# 3 D.E Infirmier
# 4 Licence - Parcours d'Accès Spécifique Santé (PASS)
# 5 Licence - Parcours d'Accès Spécifique Santé (PASS)
# 6 Licence - Administration économique et sociale
#   Sélectivité             Filière.de.formation.très.agrégée
# 1 formation sélective     Autre formation
# 2 formation non sélective Licence
# 3 formation sélective     IFSI
# 4 formation non sélective PASS
# 5 formation non sélective PASS
# 6 formation non sélective Licence
#   Filière.de.formation.1                    Coordonnées.GPS.de.la.formation
# 1 D.E secteur sanitaire                     45.74148, 4.88109
# 2 Licence - Arts-lettres-langues            48.9458, 2.36341
# 3 D.E secteur sanitaire                     46.0446, 4.07402
# 4 Licence - Sciences - technologies - santé 45.7818, 4.86821
# 5 Licence - Sciences - technologies - santé 45.74149, 4.8807
# 6 Licence - Droit-économie-gestion          44.2082, 0.62735
#   Capacité.de.l.établissement.par.formation ⋯
# 1  40                                       ⋯
# 2  32                                       ⋯
# 3  56                                       ⋯
# 4 195                                       ⋯
# 5  75                                       ⋯
# 6 110                                       ⋯
#   Part.des.terminales.technologiques.qui.étaient.en.position.de.recevoir.une.proposition.en.phase.principale
# 1 7
# 2 24
# 3 37
# 4 1
# 5 1
# 6 nd
#   Part.des.terminales.professionnelles.qui.étaient.en.position.de.recevoir.une.proposition.en.phase.principale
# 1 1
# 2 19
# 3 7
# 4 0
# 5 0
# 6 nd
#   Effectif.total.candidats.2phases Effectif.total.admis.2phases
# 1  936                              40
# 2  249                              30
# 3 2791                              56
# 4 5973                             194
# 5 5472                              75
# 6 1719                             101
#   pct_filles_admises pct_garcons_admis part_mention_ab part_mention_b
# 1 0.8250000          0.1750000         0.5384615       0.1538462
# 2 0.7666667          0.2333333         0.1666667       0.0000000
# 3 0.8928571          0.1071429         0.3513514       0.2432432
# 4 0.5360825          0.4639175         0.4245810       0.3296089
# 5 0.8666667          0.1333333         0.1549296       0.5070423
# 6 0.6633663          0.3366337         0.2500000       0.1250000
#   part_mention_tb part_mention_tb_fel
# 1 0.30769231      0.00000000
# 2 0.00000000      0.00000000
# 3 0.02702703      0.00000000
# 4 0.10055866      0.01675978
# 5 0.29577465      0.04225352
# 6 0.04166667      0.00000000

# %% [markdown]
# ## Features principales pour l'analyse
#
# On crée un jeu de features simple et cohérent avec le cours : ratios interprétables, transformations log des volumes et discrétisation par quantiles.

# %%
data <- data %>%
  rename(Statut.Etablissement = "Statut.de.l.établissement.de.la.filière.de.formation..public..privé..") 

data <- data %>%
  mutate(Statut.Etablissement = case_when(
    grepl("^Public", Statut.Etablissement) ~ "Public",
    grepl("^Privé",  Statut.Etablissement) ~ "Privé",
    TRUE ~ Statut.Etablissement  # garder les autres valeurs
  ))

data$Statut.Etablissement <- as.factor(data$Statut.Etablissement)

# %%
data <- data %>%
  mutate(
    # Total candidats et boursiers candidats (tous bacs confondus)
    total_candidats = Effectif.des.candidats.néo.bacheliers.généraux.en.phase.principale +
                      Effectif.des.candidats.néo.bacheliers.technologiques.en.phase.principale +
                      Effectif.des.candidats.néo.bacheliers.professionnels.en.phase.principale,
    
    total_boursiers_candidats = Dont.effectif.des.candidats.boursiers.néo.bacheliers.généraux.en.phase.principale +
                                Dont.effectif.des.candidats.boursiers.néo.bacheliers.technologiques.en.phase.principale +
                                Dont.effectif.des.candidats.boursiers.néo.bacheliers.professionnels.en.phase.principale,
    
    # Nouvelles features
    Pourcentage.boursiers.candidats = (total_boursiers_candidats / total_candidats) * 100,
    Pourcentage.boursiers.admis     = (Dont.effectif.des.admis.boursiers.néo.bacheliers / 
                                       Effectif.des.admis.néo.bacheliers) * 100
  ) %>%
  # Supprimer les colonnes intermédiaires
  select(-total_candidats, -total_boursiers_candidats)

# %%
glimpse(data)
summary(data)
# Out:
# Rows: 14,252
# Columns: 110
# $ Statut.Etablissement                                                                                                                             <fct> …
# $ Établissement                                                                                                                                    <fct> …
# $ Région.de.l.établissement                                                                                                                        <fct> …
# $ Académie.de.l.établissement                                                                                                                      <fct> …
# $ Filière.de.formation                                                                                                                             <fct> …
# $ Sélectivité                                                                                                                                      <fct> …
# $ Filière.de.formation.très.agrégée                                                                                                                <fct> …
# $ Filière.de.formation.1                                                                                                                           <fct> …
# $ Coordonnées.GPS.de.la.formation                                                                                                                  <fct> …
# $ Capacité.de.l.établissement.par.formation                                                                                                        <dbl> …
# $ Effectif.total.des.candidats.pour.une.formation                                                                                                  <int> …
# $ Dont.effectif.des.candidates.pour.une.formation                                                                                                  <int> …
# $ Effectif.total.des.candidats.en.phase.principale                                                                                                 <dbl> …
# $ Effectif.des.candidats.néo.bacheliers.généraux.en.phase.principale                                                                               <int> …
# $ Dont.effectif.des.candidats.boursiers.néo.bacheliers.généraux.en.phase.principale                                                                <int> …
# $ Effectif.des.candidats.néo.bacheliers.technologiques.en.phase.principale                                                                         <int> …
# $ Dont.effectif.des.candidats.boursiers.néo.bacheliers.technologiques.en.phase.principale                                                          <int> …
# $ Effectif.des.candidats.néo.bacheliers.professionnels.en.phase.principale                                                                         <int> …
# $ Dont.effectif.des.candidats.boursiers.néo.bacheliers.professionnels.en.phase.principale                                                          <int> …
# $ Effectif.des.autres.candidats.en.phase.principale                                                                                                <int> …
# $ Effectif.total.des.candidats.en.phase.complémentaire                                                                                             <dbl> …
# $ Effectif.des.candidats.néo.bacheliers.généraux.en.phase.complémentaire                                                                           <int> …
# $ Effectif.des.candidats.néo.bacheliers.technologique.en.phase.complémentaire                                                                      <int> …
# $ Effectif.des.candidats.néo.bacheliers.professionnels.en.phase.complémentaire                                                                     <int> …
# $ Effectifs.des.autres.candidats.en.phase.complémentaire                                                                                           <int> …
# $ Effectif.des.candidats.néo.bacheliers.généraux.classés.par.l.établissement                                                                       <int> …
# $ Dont.effectif.des.candidats.boursiers.néo.bacheliers.généraux.classés.par.l.établissement                                                        <int> …
# $ Effectif.des.candidats.néo.bacheliers.technologiques.classés.par.l.établissement                                                                 <int> …
# $ Dont.effectif.des.candidats.boursiers.néo.bacheliers.technologiques.classés.par.l.établissement                                                  <int> …
# $ Effectif.des.candidats.néo.bacheliers.professionnels.classés.par.l.établissement                                                                 <int> …
# $ Dont.effectif.des.candidats.boursiers.néo.bacheliers.professionnels.classés.par.l.établissement                                                  <int> …
# $ Effectif.des.autres.candidats.classés.par.l.établissement                                                                                        <int> …
# $ Effectif.total.des.candidats.ayant.reçu.une.proposition.d.admission.de.la.part.de.l.établissement                                                <int> …
# $ Effectif.total.des.candidats.ayant.accepté.la.proposition.de.l.établissement..admis.                                                             <dbl> …
# $ Dont.effectif.des.candidates.admises                                                                                                             <dbl> …
# $ Effectif.des.admis.en.phase.principale                                                                                                           <dbl> …
# $ Effectif.des.admis.en.phase.complémentaire                                                                                                       <dbl> …
# $ Dont.effectif.des.admis.ayant.reçu.leur.proposition.d.admission.à.l.ouverture.de.la.procédure.principale                                         <int> …
# $ Dont.effectif.des.admis.ayant.reçu.leur.proposition.d.admission.avant.le.baccalauréat                                                            <int> …
# $ Dont.effectif.des.admis.ayant.reçu.leur.proposition.d.admission.avant.la.fin.de.la.procédure.principale                                          <int> …
# $ Dont.effectif.des.admis.en.internat                                                                                                              <int> …
# $ Dont.effectif.des.admis.boursiers.néo.bacheliers                                                                                                 <int> …
# $ Effectif.des.admis.néo.bacheliers                                                                                                                <dbl> …
# $ Effectif.des.admis.néo.bacheliers.généraux                                                                                                       <int> …
# $ Effectif.des.admis.néo.bacheliers.technologiques                                                                                                 <int> …
# $ Effectif.des.admis.néo.bacheliers.professionnels                                                                                                 <int> …
# $ Effectif.des.autres.candidats.admis                                                                                                              <int> …
# $ Dont.effectif.des.admis.néo.bacheliers.sans.information.sur.la.mention.au.bac                                                                    <int> …
# $ Dont.effectif.des.admis.néo.bacheliers.sans.mention.au.bac                                                                                       <dbl> …
# $ Dont.effectif.des.admis.néo.bacheliers.avec.mention.Assez.Bien.au.bac                                                                            <dbl> …
# $ Dont.effectif.des.admis.néo.bacheliers.avec.mention.Bien.au.bac                                                                                  <dbl> …
# $ Dont.effectif.des.admis.néo.bacheliers.avec.mention.Très.Bien.au.bac                                                                             <dbl> …
# $ Dont.effectif.des.admis.néo.bacheliers.avec.mention.Très.Bien.avec.félicitations.au.bac                                                          <dbl> …
# $ Effectif.des.admis.néo.bacheliers.généraux.ayant.eu.une.mention.au.bac                                                                           <int> …
# $ Effectif.des.admis.néo.bacheliers.technologiques.ayant.eu.une.mention.au.bac                                                                     <int> …
# $ Effectif.des.admis.néo.bacheliers.professionnels.ayant.eu.une.mention.au.bac                                                                     <int> …
# $ Dont.effectif.des.admis.issus.du.même.établissement..BTS.CPGE.                                                                                   <int> …
# $ Dont.effectif.des.admises.issues.du.même.établissement..BTS.CPGE.                                                                                <int> …
# $ Dont.effectif.des.admis.issus.de.la.même.académie                                                                                                <int> …
# $ Dont.effectif.des.admis.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies.                                                             <int> …
# $ X..d.admis.ayant.reçu.leur.proposition.d.admission.à.l.ouverture.de.la.procédure.principale                                                      <dbl> …
# $ X..d.admis.ayant.reçu.leur.proposition.d.admission.avant.le.baccalauréat                                                                         <dbl> …
# $ X..d.admis.ayant.reçu.leur.proposition.d.admission.avant.la.fin.de.la.procédure.principale                                                       <dbl> …
# $ X..d.admis.dont.filles                                                                                                                           <dbl> …
# $ X..d.admis.néo.bacheliers.issus.de.la.même.académie                                                                                              <dbl> …
# $ X..d.admis.néo.bacheliers.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies.                                                           <dbl> …
# $ X..d.admis.néo.bacheliers.issus.du.même.établissement..BTS.CPGE.                                                                                 <dbl> …
# $ X..d.admis.néo.bacheliers.boursiers                                                                                                              <dbl> …
# $ X..d.admis.néo.bacheliers                                                                                                                        <dbl> …
# $ X..d.admis.néo.bacheliers.sans.information.sur.la.mention.au.bac                                                                                 <dbl> …
# $ X..d.admis.néo.bacheliers.sans.mention.au.bac                                                                                                    <dbl> …
# $ X..d.admis.néo.bacheliers.avec.mention.Assez.Bien.au.bac                                                                                         <dbl> …
# $ X..d.admis.néo.bacheliers.avec.mention.Bien.au.bac                                                                                               <dbl> …
# $ X..d.admis.néo.bacheliers.avec.mention.Très.Bien.au.bac                                                                                          <dbl> …
# $ X..d.admis.néo.bacheliers.avec.mention.Très.Bien.avec.félicitations.au.bac                                                                       <dbl> …
# $ X..d.admis.néo.bacheliers.généraux                                                                                                               <dbl> …
# $ Dont...d.admis.avec.mention..BG.                                                                                                                 <dbl> …
# $ X..d.admis.néo.bacheliers.technologiques                                                                                                         <dbl> …
# $ Dont...d.admis.avec.mention..BT.                                                                                                                 <dbl> …
# $ X..d.admis.néo.bacheliers.professionnels                                                                                                         <dbl> …
# $ Dont...d.admis.avec.mention..BP.                                                                                                                 <dbl> …
# $ Effectif.des.candidats.en.terminale.générale.ayant.reçu.une.proposition.d.admission.de.la.part.de.l.établissement                                <dbl> …
# $ Dont.effectif.des.candidats.boursiers.en.terminale.générale.ayant.reçu.une.proposition.d.admission.de.la.part.de.l.établissement                 <dbl> …
# $ Effectif.des.candidats.en.terminale.technologique.ayant.reçu.une.proposition.d.admission.de.la.part.de.l.établissement                           <dbl> …
# $ Dont.effectif.des.candidats.boursiers.en.terminale.technologique.ayant.reçu.une.proposition.d.admission.de.la.part.de.l.établissement            <dbl> …
# $ Effectif.des.candidats.en.terminale.professionnelle.ayant.reçu.une.proposition.d.admission.de.la.part.de.l.établissement                         <dbl> …
# $ Dont.effectif.des.candidats.boursiers.en.terminale.générale.professionnelle.ayant.reçu.une.proposition.d.admission.de.la.part.de.l.établissement <dbl> …
# $ Effectif.des.autres.candidats.ayant.reçu.une.proposition.d.admission.de.la.part.de.l.établissement                                               <dbl> …
# $ Regroupement.1.effectué.par.les.formations.pour.les.classements                                                                                  <fct> …
# $ Rang.du.dernier.appelé.du.groupe.1                                                                                                               <fct> …
# $ Regroupement.2.effectué.par.les.formations.pour.les.classements                                                                                  <fct> …
# $ Rang.du.dernier.appelé.du.groupe.2                                                                                                               <int> …
# $ Regroupement.3.effectué.par.les.formations.pour.les.classements                                                                                  <fct> …
# $ Rang.du.dernier.appelé.du.groupe.3                                                                                                               <int> …
# $ list_com                                                                                                                                         <fct> …
# $ tri                                                                                                                                              <fct> …
# $ Taux.d.accès                                                                                                                                     <fct> …
# $ Part.des.terminales.générales.qui.étaient.en.position.de.recevoir.une.proposition.en.phase.principale                                            <fct> …
# $ Part.des.terminales.technologiques.qui.étaient.en.position.de.recevoir.une.proposition.en.phase.principale                                       <fct> …
# $ Part.des.terminales.professionnelles.qui.étaient.en.position.de.recevoir.une.proposition.en.phase.principale                                     <fct> …
# $ Effectif.total.candidats.2phases                                                                                                                 <dbl> …
# $ Effectif.total.admis.2phases                                                                                                                     <dbl> …
# $ pct_filles_admises                                                                                                                               <dbl> …
# $ pct_garcons_admis                                                                                                                                <dbl> …
# $ part_mention_ab                                                                                                                                  <dbl> …
# $ part_mention_b                                                                                                                                   <dbl> …
# $ part_mention_tb                                                                                                                                  <dbl> …
# $ part_mention_tb_fel                                                                                                                              <dbl> …
# $ Pourcentage.boursiers.candidats                                                                                                                  <dbl> …
# $ Pourcentage.boursiers.admis                                                                                                                      <dbl> …
#  Statut.Etablissement                                    Établissement
#  Privé : 3144         Université de Lille                       :  124
#  Public:11108         Université de Strasbourg                  :  103
#                       Sorbonne université                       :   98
#                       Université Paris Cité                     :   98
#                       Université Lyon 2 - Campus Porte des Alpes:   97
#                       Université Sorbonne Nouvelle Paris 3      :   92
#                       (Other)                                   :13640
#         Région.de.l.établissement Académie.de.l.établissement
#  Ile-de-France       :2691        Paris     :1034
#  Auvergne-Rhône-Alpes:1730        Lille     : 960
#  Hauts-de-France     :1272        Versailles: 875
#  Occitanie           :1218        Nantes    : 840
#  Nouvelle Aquitaine  :1162        Lyon      : 832
#  Grand-Est           :1150        Créteil   : 782
#  (Other)             :5029        (Other)   :8929
#                                                            Filière.de.formation
#  BTS - Services - Management Commercial Opérationnel                 :  348
#  D.E Infirmier                                                       :  341
#  BTS - Services - Comptabilité et gestion                            :  335
#  Licence - Parcours d'Accès Spécifique Santé (PASS)                  :  287
#  BTS - Services - Gestion de la PME                                  :  276
#  BTS - Services - Négociation et digitalisation de la Relation Client:  249
#  (Other)                                                             :12416
#                   Sélectivité    Filière.de.formation.très.agrégée
#  formation non sélective: 3196   BTS              :5351
#  formation sélective    :11056   Licence          :3052
#                                  Autre formation  :1815
#                                  CPGE             : 986
#                                  BUT              : 820
#                                  Ecole d'Ingénieur: 585
#                                  (Other)          :1643
#                                Filière.de.formation.1
#  BTS - Services                           :3096
#  BTS - Production                         :1711
#  Licence - Arts-lettres-langues           :1252
#  Licence - Sciences - technologies - santé:1227
#  Licence - Sciences humaines et sociales  : 694
#  Licence - Droit-économie-gestion         : 640
#  (Other)                                  :5632
#    Coordonnées.GPS.de.la.formation Capacité.de.l.établissement.par.formation
#  48.8452, 2.39666  :   92          Min.   :   0.00
#  48.9035, 2.21449  :   85          1st Qu.:  18.00
#  48.8274, 2.37623  :   79          Median :  30.00
#  43.51478, 5.44706 :   61          Mean   :  53.98
#  43.5784, 1.40266  :   57          3rd Qu.:  50.00
#  48.12162, -1.70445:   54          Max.   :3400.00
#  (Other)           :13824
#  Effectif.total.des.candidats.pour.une.formation
#  Min.   :    1.0
#  1st Qu.:  160.0
#  Median :  385.0
#  Mean   :  947.4
#  3rd Qu.: 1016.0
#  Max.   :19404.0
#
#  Dont.effectif.des.candidates.pour.une.formation
#  Min.   :    0.0
#  1st Qu.:   58.0
#  Median :  193.0
#  Mean   :  533.8
#  3rd Qu.:  529.0
#  Max.   :14569.0
#
#  Effectif.total.des.candidats.en.phase.principale
#  Min.   :    0.0
#  1st Qu.:  137.0
#  Median :  348.0
#  Mean   :  915.8
#  3rd Qu.:  964.0
#  Max.   :19404.0
#
#  Effectif.des.candidats.néo.bacheliers.généraux.en.phase.principale
#  Min.   :    0
#  1st Qu.:   24
#  Median :  101
#  Mean   :  475
#  3rd Qu.:  433
#  Max.   :15301
#
#  Dont.effectif.des.candidats.boursiers.néo.bacheliers.généraux.en.phase.principale
#  Min.   :   0.00
#  1st Qu.:   3.00
#  Median :  17.00
#  Mean   :  65.53
#  3rd Qu.:  63.00
#  Max.   :2200.00
#
#  Effectif.des.candidats.néo.bacheliers.technologiques.en.phase.principale
#  Min.   :   0.0
#  1st Qu.:  13.0
#  Median :  45.0
#  Mean   : 125.8
#  3rd Qu.: 125.0
#  Max.   :4920.0
#
#  Dont.effectif.des.candidats.boursiers.néo.bacheliers.technologiques.en.phase.principale
#  Min.   :   0.00
#  1st Qu.:   2.00
#  Median :   9.00
#  Mean   :  33.93
#  3rd Qu.:  31.00
#  Max.   :1711.00
#
#  Effectif.des.candidats.néo.bacheliers.professionnels.en.phase.principale
#  Min.   :   0.00
#  1st Qu.:   6.00
#  Median :  24.00
#  Mean   :  66.54
#  3rd Qu.:  67.00
#  Max.   :2047.00
#
#  Dont.effectif.des.candidats.boursiers.néo.bacheliers.professionnels.en.phase.principale
#  Min.   :  0.00
#  1st Qu.:  2.00
#  Median :  7.00
#  Mean   : 24.18
#  3rd Qu.: 21.00
#  Max.   :890.00
#
#  Effectif.des.autres.candidats.en.phase.principale
#  Min.   :   0.0
#  1st Qu.:  30.0
#  Median :  86.0
#  Mean   : 248.4
#  3rd Qu.: 252.0
#  Max.   :7550.0
#
#  Effectif.total.des.candidats.en.phase.complémentaire
#  Min.   :   0.00
#  1st Qu.:   0.00
#  Median :   3.00
#  Mean   :  31.59
#  3rd Qu.:  25.00
#  Max.   :3532.00
#
#  Effectif.des.candidats.néo.bacheliers.généraux.en.phase.complémentaire
#  Min.   :   0.000
#  1st Qu.:   0.000
#  Median :   0.000
#  Mean   :   6.832
#  3rd Qu.:   3.000
#  Max.   :1395.000
#
#  Effectif.des.candidats.néo.bacheliers.technologique.en.phase.complémentaire
#  Min.   :  0.000
#  1st Qu.:  0.000
#  Median :  0.000
#  Mean   :  3.942
#  3rd Qu.:  3.000
#  Max.   :734.000
#
#  Effectif.des.candidats.néo.bacheliers.professionnels.en.phase.complémentaire
#  Min.   :  0.000
#  1st Qu.:  0.000
#  Median :  0.000
#  Mean   :  2.533
#  3rd Qu.:  2.000
#  Max.   :219.000
#
#  Effectifs.des.autres.candidats.en.phase.complémentaire
#  Min.   :   0.00
#  1st Qu.:   0.00
#  Median :   1.00
#  Mean   :  18.28
#  3rd Qu.:  14.00
#  Max.   :1774.00
#
#  Effectif.des.candidats.néo.bacheliers.généraux.classés.par.l.établissement
#  Min.   :    0
#  1st Qu.:   18
#  Median :   70
#  Mean   :  375
#  3rd Qu.:  338
#  Max.   :14315
#
#  Dont.effectif.des.candidats.boursiers.néo.bacheliers.généraux.classés.par.l.établissement
#  Min.   :   0.0
#  1st Qu.:   2.0
#  Median :  10.0
#  Mean   :  51.6
#  3rd Qu.:  44.0
#  Max.   :2200.0
#
#  Effectif.des.candidats.néo.bacheliers.technologiques.classés.par.l.établissement
#  Min.   :   0.00
#  1st Qu.:   8.00
#  Median :  35.00
#  Mean   :  87.23
#  3rd Qu.:  93.00
#  Max.   :2725.00
#
#  Dont.effectif.des.candidats.boursiers.néo.bacheliers.technologiques.classés.par.l.établissement
#  Min.   :  0.00
#  1st Qu.:  1.00
#  Median :  7.00
#  Mean   : 21.81
#  3rd Qu.: 22.00
#  Max.   :911.00
#
#  Effectif.des.candidats.néo.bacheliers.professionnels.classés.par.l.établissement
#  Min.   :   0.00
#  1st Qu.:   1.00
#  Median :  16.00
#  Mean   :  45.87
#  3rd Qu.:  50.00
#  Max.   :2040.00
#
#  Dont.effectif.des.candidats.boursiers.néo.bacheliers.professionnels.classés.par.l.établissement
#  Min.   :  0.00
#  1st Qu.:  0.00
#  Median :  4.00
#  Mean   : 15.82
#  3rd Qu.: 15.00
#  Max.   :890.00
#
#  Effectif.des.autres.candidats.classés.par.l.établissement
#  Min.   :   0.0
#  1st Qu.:  13.0
#  Median :  36.0
#  Mean   : 149.6
#  3rd Qu.: 112.0
#  Max.   :7526.0
#
#  Effectif.total.des.candidats.ayant.reçu.une.proposition.d.admission.de.la.part.de.l.établissement
#  Min.   :   0.0
#  1st Qu.:  64.0
#  Median : 127.0
#  Mean   : 290.5
#  3rd Qu.: 292.0
#  Max.   :5905.0
#
#  Effectif.total.des.candidats.ayant.accepté.la.proposition.de.l.établissement..admis.
#  Min.   :   0.00
#  1st Qu.:  14.00
#  Median :  25.00
#  Mean   :  46.36
#  3rd Qu.:  46.00
#  Max.   :2187.00
#
#  Dont.effectif.des.candidates.admises Effectif.des.admis.en.phase.principale
#  Min.   :   0.00                      Min.   :   0.00
#  1st Qu.:   4.00                      1st Qu.:  12.00
#  Median :  12.00                      Median :  23.00
#  Mean   :  26.09                      Mean   :  42.28
#  3rd Qu.:  26.00                      3rd Qu.:  41.00
#  Max.   :1562.00                      Max.   :2187.00
#
#  Effectif.des.admis.en.phase.complémentaire
#  Min.   :  0.000
#  1st Qu.:  0.000
#  Median :  0.000
#  Mean   :  4.082
#  3rd Qu.:  3.000
#  Max.   :332.000
#
#  Dont.effectif.des.admis.ayant.reçu.leur.proposition.d.admission.à.l.ouverture.de.la.procédure.principale
#  Min.   :   0.00
#  1st Qu.:   3.00
#  Median :   7.00
#  Mean   :  17.92
#  3rd Qu.:  17.00
#  Max.   :2177.00
#
#  Dont.effectif.des.admis.ayant.reçu.leur.proposition.d.admission.avant.le.baccalauréat
#  Min.   :   0.00
#  1st Qu.:   9.00
#  Median :  17.00
#  Mean   :  33.03
#  3rd Qu.:  32.00
#  Max.   :2187.00
#
#  Dont.effectif.des.admis.ayant.reçu.leur.proposition.d.admission.avant.la.fin.de.la.procédure.principale
#  Min.   :   0.0
#  1st Qu.:  12.0
#  Median :  22.0
#  Mean   :  41.4
#  3rd Qu.:  41.0
#  Max.   :2187.0
#
#  Dont.effectif.des.admis.en.internat
#  Min.   :  0.00
#  1st Qu.:  0.00
#  Median :  7.00
#  Mean   : 11.18
#  3rd Qu.: 16.00
#  Max.   :140.00
#  NA's   :13266
#  Dont.effectif.des.admis.boursiers.néo.bacheliers
#  Min.   :  0.000
#  1st Qu.:  1.000
#  Median :  4.000
#  Mean   :  6.951
#  3rd Qu.:  8.000
#  Max.   :255.000
#
#  Effectif.des.admis.néo.bacheliers Effectif.des.admis.néo.bacheliers.généraux
#  Min.   :   0.00                   Min.   :   0.00
#  1st Qu.:  10.00                   1st Qu.:   2.00
#  Median :  19.00                   Median :   6.00
#  Mean   :  34.05                   Mean   :  23.28
#  3rd Qu.:  34.00                   3rd Qu.:  24.00
#  Max.   :1197.00                   Max.   :1197.00
#
#  Effectif.des.admis.néo.bacheliers.technologiques
#  Min.   :  0.000
#  1st Qu.:  0.000
#  Median :  3.000
#  Mean   :  6.634
#  3rd Qu.:  8.000
#  Max.   :163.000
#
#  Effectif.des.admis.néo.bacheliers.professionnels
#  Min.   : 0.000
#  1st Qu.: 0.000
#  Median : 2.000
#  Mean   : 4.137
#  3rd Qu.: 7.000
#  Max.   :88.000
#
#  Effectif.des.autres.candidats.admis
#  Min.   :   0.00
#  1st Qu.:   2.00
#  Median :   5.00
#  Mean   :  12.31
#  3rd Qu.:  12.00
#  Max.   :1699.00
#
#  Dont.effectif.des.admis.néo.bacheliers.sans.information.sur.la.mention.au.bac
#  Min.   :0.0000
#  1st Qu.:0.0000
#  Median :0.0000
#  Mean   :0.0442
#  3rd Qu.:0.0000
#  Max.   :9.0000
#
#  Dont.effectif.des.admis.néo.bacheliers.sans.mention.au.bac
#  Min.   :  0.00
#  1st Qu.:  2.00
#  Median :  5.00
#  Mean   : 10.12
#  3rd Qu.: 11.00
#  Max.   :292.00
#
#  Dont.effectif.des.admis.néo.bacheliers.avec.mention.Assez.Bien.au.bac
#  Min.   :  0.00
#  1st Qu.:  3.00
#  Median :  6.00
#  Mean   : 11.36
#  3rd Qu.: 11.00
#  Max.   :458.00
#
#  Dont.effectif.des.admis.néo.bacheliers.avec.mention.Bien.au.bac
#  Min.   :  0.000
#  1st Qu.:  1.000
#  Median :  3.000
#  Mean   :  8.326
#  3rd Qu.:  8.000
#  Max.   :550.000
#
#  Dont.effectif.des.admis.néo.bacheliers.avec.mention.Très.Bien.au.bac
#  Min.   :  0.000
#  1st Qu.:  0.000
#  Median :  1.000
#  Mean   :  3.679
#  3rd Qu.:  2.000
#  Max.   :405.000
#
#  Dont.effectif.des.admis.néo.bacheliers.avec.mention.Très.Bien.avec.félicitations.au.bac
#  Min.   :  0.0000
#  1st Qu.:  0.0000
#  Median :  0.0000
#  Mean   :  0.5123
#  3rd Qu.:  0.0000
#  Max.   :226.0000
#
#  Effectif.des.admis.néo.bacheliers.généraux.ayant.eu.une.mention.au.bac
#  Min.   :   0.00
#  1st Qu.:   0.00
#  Median :   3.00
#  Mean   :  17.22
#  3rd Qu.:  17.00
#  Max.   :1161.00
#
#  Effectif.des.admis.néo.bacheliers.technologiques.ayant.eu.une.mention.au.bac
#  Min.   :  0.000
#  1st Qu.:  0.000
#  Median :  1.000
#  Mean   :  3.656
#  3rd Qu.:  4.000
#  Max.   :158.000
#
#  Effectif.des.admis.néo.bacheliers.professionnels.ayant.eu.une.mention.au.bac
#  Min.   : 0.000
#  1st Qu.: 0.000
#  Median : 1.000
#  Mean   : 3.007
#  3rd Qu.: 5.000
#  Max.   :50.000
#
#  Dont.effectif.des.admis.issus.du.même.établissement..BTS.CPGE.
#  Min.   : 0.000
#  1st Qu.: 1.000
#  Median : 3.000
#  Mean   : 3.846
#  3rd Qu.: 5.000
#  Max.   :45.000
#  NA's   :7915
#  Dont.effectif.des.admises.issues.du.même.établissement..BTS.CPGE.
#  Min.   : 0.000
#  1st Qu.: 0.000
#  Median : 0.000
#  Mean   : 1.451
#  3rd Qu.: 2.000
#  Max.   :25.000
#  NA's   :7915
#  Dont.effectif.des.admis.issus.de.la.même.académie
#  Min.   :   0.00
#  1st Qu.:   6.00
#  Median :  13.00
#  Mean   :  23.73
#  3rd Qu.:  24.00
#  Max.   :1024.00
#
#  Dont.effectif.des.admis.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies.
#  Min.   :   0.0
#  1st Qu.:   7.0
#  Median :  14.0
#  Mean   :  26.3
#  3rd Qu.:  27.0
#  Max.   :1065.0
#
#  X..d.admis.ayant.reçu.leur.proposition.d.admission.à.l.ouverture.de.la.procédure.principale
# ...
#  X..d.admis.néo.bacheliers.technologiques Dont...d.admis.avec.mention..BT.
#  Min.   :  0.00                           Min.   :  0.0
#  1st Qu.:  0.00                           1st Qu.:  0.0
#  Median : 20.00                           Median :  6.0
#  Mean   : 24.41                           Mean   : 12.1
#  3rd Qu.: 40.00                           3rd Qu.: 18.0
#  Max.   :100.00                           Max.   :100.0
#
#  X..d.admis.néo.bacheliers.professionnels Dont...d.admis.avec.mention..BP.
#  Min.   :  0.00                           Min.   :  0.00
#  1st Qu.:  0.00                           1st Qu.:  0.00
#  Median : 10.00                           Median :  6.00
#  Mean   : 23.45                           Mean   : 16.25
#  3rd Qu.: 43.00                           3rd Qu.: 29.00
#  Max.   :100.00                           Max.   :100.00
#
#  Effectif.des.candidats.en.terminale.générale.ayant.reçu.une.proposition.d.admission.de.la.part.de.l.établissement
#  Min.   :   0.0
#  1st Qu.:  11.0
#  Median :  36.0
#  Mean   : 174.5
#  3rd Qu.: 187.0
#  Max.   :5502.0
#
#  Dont.effectif.des.candidats.boursiers.en.terminale.générale.ayant.reçu.une.proposition.d.admission.de.la.part.de.l.établissement
#  Min.   :  0.00
#  1st Qu.:  2.00
#  Median :  6.00
#  Mean   : 24.42
#  3rd Qu.: 26.00
#  Max.   :686.00
#
#  Effectif.des.candidats.en.terminale.technologique.ayant.reçu.une.proposition.d.admission.de.la.part.de.l.établissement
#  Min.   :  0.00
#  1st Qu.:  3.00
#  Median : 18.00
#  Mean   : 37.16
#  3rd Qu.: 43.00
#  Max.   :660.00
#
#  Dont.effectif.des.candidats.boursiers.en.terminale.technologique.ayant.reçu.une.proposition.d.admission.de.la.part.de.l.établissement
#  Min.   :  0.000
#  1st Qu.:  0.000
#  Median :  4.000
#  Mean   :  9.418
#  3rd Qu.: 11.000
#  Max.   :267.000
#
#  Effectif.des.candidats.en.terminale.professionnelle.ayant.reçu.une.proposition.d.admission.de.la.part.de.l.établissement
#  Min.   :  0.0
#  1st Qu.:  0.0
#  Median :  8.0
#  Mean   : 17.9
#  3rd Qu.: 27.0
#  Max.   :274.0
#
#  Dont.effectif.des.candidats.boursiers.en.terminale.générale.professionnelle.ayant.reçu.une.proposition.d.admission.de.la.part.de.l.établissement
#  Min.   :  0.000
#  1st Qu.:  0.000
#  Median :  2.000
#  Mean   :  6.205
#  3rd Qu.:  8.250
#  Max.   :188.000
#
#  Effectif.des.autres.candidats.ayant.reçu.une.proposition.d.admission.de.la.part.de.l.établissement
#  Min.   :   0.00
#  1st Qu.:   8.00
#  Median :  21.00
#  Mean   :  60.92
#  3rd Qu.:  53.00
#  Max.   :3006.00
#
#         Regroupement.1.effectué.par.les.formations.pour.les.classements
#  Tous les candidats                     :6973
#  Autres candidats                       :5988
#                                         :1268
#  Voie d'acces generale                  :   9
#  Bacheliers professionnels toutes series:   5
#  Groupe par defaut                      :   4
#  (Other)                                :   5
#  Rang.du.dernier.appelé.du.groupe.1
#  nd     : 1119
#  16     :  141
#  11     :  139
#  12     :  134
#  14     :  134
#  21     :  129
#  (Other):12456
#         Regroupement.2.effectué.par.les.formations.pour.les.classements
#                                         :8269
#  Bacheliers professionnels toutes series:4813
#  Bacheliers technologiques toutes series:1156
#  Tous les garcons                       :   4
#  Toutes les filles                      :   1
#  Voie d'acces CEP                       :   9
#
#  Rang.du.dernier.appelé.du.groupe.2
#  Min.   :  1.00
#  1st Qu.: 24.00
#  Median : 43.00
#  Mean   : 64.28
#  3rd Qu.: 75.00
#  Max.   :921.00
#  NA's   :8110
#         Regroupement.3.effectué.par.les.formations.pour.les.classements
#                                         :10791
#  Bacheliers professionnels toutes series:  347
#  Bacheliers technologiques toutes series: 3114
#
#
#
#
#  Rang.du.dernier.appelé.du.groupe.3
#  Min.   :  1.00
#  1st Qu.: 26.00
#  Median : 48.00
#  Mean   : 59.86
#  3rd Qu.: 81.00
#  Max.   :494.00
#  NA's   :10586
#                                          list_com
#  Liste d'appel commune à plusieurs formations:12354
#  Liste d'appel propre à cette formation      : 1898
#
#
#
#
#
#                   tri        Taux.d.accès
#  1_universités      :4672   100    : 1125
#  2_Lycées           :6337   nd     : 1119
#  3_Autres formations:3243   99     :  313
#                             98     :  223
#                             88     :  174
#                             44     :  157
#                             (Other):11141
#  Part.des.terminales.générales.qui.étaient.en.position.de.recevoir.une.proposition.en.phase.principale
#  100    : 2018
#  nd     : 1119
#  0      :  472
#  99     :  227
#  12     :  185
#  18     :  178
#  (Other):10053
#  Part.des.terminales.technologiques.qui.étaient.en.position.de.recevoir.une.proposition.en.phase.principale
#  0      :2326
#  nd     :1119
#  10     : 260
#  39     : 260
#  1      : 241
#  33     : 240
#  (Other):9806
#  Part.des.terminales.professionnelles.qui.étaient.en.position.de.recevoir.une.proposition.en.phase.principale
#  0      :3893
#  nd     :1119
#  1      : 499
#  2      : 402
#  3      : 348
#  4      : 338
#  (Other):7653
#  Effectif.total.candidats.2phases Effectif.total.admis.2phases
#  Min.   :    1.0                  Min.   :   0.00
#  1st Qu.:  160.0                  1st Qu.:  14.00
#  Median :  385.0                  Median :  25.00
#  Mean   :  947.4                  Mean   :  46.36
#  3rd Qu.: 1016.0                  3rd Qu.:  46.00
#  Max.   :19404.0                  Max.   :2187.00
#
#  pct_filles_admises pct_garcons_admis part_mention_ab  part_mention_b
#  Min.   :0.0000     Min.   :0.0000    Min.   :0.0000   Min.   :0.00000
#  1st Qu.:0.2613     1st Qu.:0.2500    1st Qu.:0.2308   1st Qu.:0.09091
#  Median :0.5357     Median :0.4643    Median :0.3333   Median :0.18182
#  Mean   :0.5063     Mean   :0.4937    Mean   :0.3334   Mean   :0.21501
#  3rd Qu.:0.7500     3rd Qu.:0.7387    3rd Qu.:0.4400   3rd Qu.:0.31250
#  Max.   :1.0000     Max.   :1.0000    Max.   :1.0000   Max.   :1.00000
#  NA's   :179        NA's   :179       NA's   :298      NA's   :298
#  part_mention_tb   part_mention_tb_fel Pourcentage.boursiers.candidats
#  Min.   :0.00000   Min.   :0.00000     Min.   :  0.00
#  1st Qu.:0.00000   1st Qu.:0.00000     1st Qu.: 12.76
#  Median :0.02941   Median :0.00000     Median : 19.48
#  Mean   :0.08477   Mean   :0.00986     Mean   : 21.23
#  3rd Qu.:0.10000   3rd Qu.:0.00000     3rd Qu.: 27.72
#  Max.   :1.00000   Max.   :1.00000     Max.   :100.00
#  NA's   :298       NA's   :298         NA's   :50
#  Pourcentage.boursiers.admis
#  Min.   :  0.00
#  1st Qu.: 10.00
#  Median : 20.00
#  Mean   : 22.75
#  3rd Qu.: 32.15
#  Max.   :100.00
#  NA's   :298

# %% [markdown]
# maintenant on créé les features, on réarange pour limiter le nombre de variables répétitives

# %%
# Conversion de Taux.d.accès (texte) en proportion numérique [0,1]
data <- data %>%
  mutate(
    taux_acces_num = suppressWarnings(as.numeric(gsub(',', '.', gsub('%', '', Taux.d.accès)))) / 100
  )

data_features_core <- data %>%
  mutate(
    # Intensité de la demande vs places disponibles
    pression_candidature = if_else(Capacité.de.l.établissement.par.formation > 0,
      Effectif.total.candidats.2phases / Capacité.de.l.établissement.par.formation, NA_real_),

    # Probabilité d'être admis parmi les candidats
    taux_admission = if_else(Effectif.total.candidats.2phases > 0,
      Effectif.total.admis.2phases / Effectif.total.candidats.2phases, NA_real_),

    # Niveau de remplissage de la capacité
    taux_remplissage = if_else(Capacité.de.l.établissement.par.formation > 0,
      Effectif.total.admis.2phases / Capacité.de.l.établissement.par.formation, NA_real_),

    # Regroupement des meilleures mentions
    part_mention_haute = part_mention_tb + part_mention_tb_fel,

    # Score synthétique (pondération croissante avec le niveau de mention)
    score_mention = 1 * coalesce(part_mention_ab, 0) +
      2 * coalesce(part_mention_b, 0) +
      3 * coalesce(part_mention_tb, 0) +
      4 * coalesce(part_mention_tb_fel, 0),

    # log1p stabilise les variables de volume très asymétriques
    log_candidats = log1p(Effectif.total.candidats.2phases),
    log_admis = log1p(Effectif.total.admis.2phases),
    log_capacite = log1p(Capacité.de.l.établissement.par.formation),

    # Discrétisation en quartiles (1 = faible, 4 = élevé)
    pression_q = ntile(pression_candidature, 4),
    taux_acces_q = ntile(taux_acces_num, 4)
  ) %>%
  # Sélection du sous-ensemble de variables pour l'analyse
  select(
    Établissement, Statut.Etablissement, Filière.de.formation, Filière.de.formation.très.agrégée,
    Région.de.l.établissement, Académie.de.l.établissement, Coordonnées.GPS.de.la.formation,	Sélectivité,Capacité.de.l.établissement.par.formation, Effectif.total.admis.2phases,Effectif.total.candidats.2phases,
    Pourcentage.boursiers.candidats,Pourcentage.boursiers.admis,
    pct_filles_admises, pct_garcons_admis,
    pression_candidature, taux_admission, taux_remplissage, taux_acces_num,
    part_mention_ab, part_mention_b, part_mention_tb, part_mention_tb_fel, part_mention_haute, score_mention,
    X..d.admis.néo.bacheliers.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies.,
    X..d.admis.néo.bacheliers.généraux,
    X..d.admis.néo.bacheliers.technologiques,
    X..d.admis.néo.bacheliers.professionnels,
    log_candidats,
    log_admis,
    log_capacite
  )

# Vérification rapide du jeu de features final
glimpse(data_features_core)
summary(select(data_features_core, where(is.numeric)))
# Out:
# Rows: 14,252
# Columns: 32
# $ Établissement                                                                          <fct> …
# $ Statut.Etablissement                                                                   <fct> …
# $ Filière.de.formation                                                                   <fct> …
# $ Filière.de.formation.très.agrégée                                                      <fct> …
# $ Région.de.l.établissement                                                              <fct> …
# $ Académie.de.l.établissement                                                            <fct> …
# $ Coordonnées.GPS.de.la.formation                                                        <fct> …
# $ Sélectivité                                                                            <fct> …
# $ Capacité.de.l.établissement.par.formation                                              <dbl> …
# $ Effectif.total.admis.2phases                                                           <dbl> …
# $ Effectif.total.candidats.2phases                                                       <dbl> …
# $ Pourcentage.boursiers.candidats                                                        <dbl> …
# $ Pourcentage.boursiers.admis                                                            <dbl> …
# $ pct_filles_admises                                                                     <dbl> …
# $ pct_garcons_admis                                                                      <dbl> …
# $ pression_candidature                                                                   <dbl> …
# $ taux_admission                                                                         <dbl> …
# $ taux_remplissage                                                                       <dbl> …
# $ taux_acces_num                                                                         <dbl> …
# $ part_mention_ab                                                                        <dbl> …
# $ part_mention_b                                                                         <dbl> …
# $ part_mention_tb                                                                        <dbl> …
# $ part_mention_tb_fel                                                                    <dbl> …
# $ part_mention_haute                                                                     <dbl> …
# $ score_mention                                                                          <dbl> …
# $ X..d.admis.néo.bacheliers.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies. <dbl> …
# $ X..d.admis.néo.bacheliers.généraux                                                     <dbl> …
# $ X..d.admis.néo.bacheliers.technologiques                                               <dbl> …
# $ X..d.admis.néo.bacheliers.professionnels                                               <dbl> …
# $ log_candidats                                                                          <dbl> …
# $ log_admis                                                                              <dbl> …
# $ log_capacite                                                                           <dbl> …
#  Capacité.de.l.établissement.par.formation Effectif.total.admis.2phases
#  Min.   :   0.00                           Min.   :   0.00
#  1st Qu.:  18.00                           1st Qu.:  14.00
#  Median :  30.00                           Median :  25.00
#  Mean   :  53.98                           Mean   :  46.36
#  3rd Qu.:  50.00                           3rd Qu.:  46.00
#  Max.   :3400.00                           Max.   :2187.00
#
#  Effectif.total.candidats.2phases Pourcentage.boursiers.candidats
#  Min.   :    1.0                  Min.   :  0.00
#  1st Qu.:  160.0                  1st Qu.: 12.76
#  Median :  385.0                  Median : 19.48
#  Mean   :  947.4                  Mean   : 21.23
#  3rd Qu.: 1016.0                  3rd Qu.: 27.72
#  Max.   :19404.0                  Max.   :100.00
#                                   NA's   :50
#  Pourcentage.boursiers.admis pct_filles_admises pct_garcons_admis
#  Min.   :  0.00              Min.   :0.0000     Min.   :0.0000
#  1st Qu.: 10.00              1st Qu.:0.2613     1st Qu.:0.2500
#  Median : 20.00              Median :0.5357     Median :0.4643
#  Mean   : 22.75              Mean   :0.5063     Mean   :0.4937
#  3rd Qu.: 32.15              3rd Qu.:0.7500     3rd Qu.:0.7387
#  Max.   :100.00              Max.   :1.0000     Max.   :1.0000
#  NA's   :298                 NA's   :179        NA's   :179
#  pression_candidature taux_admission    taux_remplissage taux_acces_num
#  Min.   :  0.050      Min.   :0.00000   Min.   :0.0000   Min.   :0.010
#  1st Qu.:  6.171      1st Qu.:0.03618   1st Qu.:0.7312   1st Qu.:0.330
#  Median : 11.417      Median :0.07007   Median :0.9333   Median :0.580
#  Mean   : 21.104      Mean   :0.08753   Mean   :0.8356   Mean   :0.583
#  3rd Qu.: 23.500      3rd Qu.:0.11996   3rd Qu.:1.0000   3rd Qu.:0.860
#  Max.   :904.667      Max.   :1.00000   Max.   :2.9412   Max.   :1.000
#  NA's   :4                              NA's   :4        NA's   :1176
#  part_mention_ab  part_mention_b    part_mention_tb   part_mention_tb_fel
#  Min.   :0.0000   Min.   :0.00000   Min.   :0.00000   Min.   :0.00000
#  1st Qu.:0.2308   1st Qu.:0.09091   1st Qu.:0.00000   1st Qu.:0.00000
#  Median :0.3333   Median :0.18182   Median :0.02941   Median :0.00000
#  Mean   :0.3334   Mean   :0.21501   Mean   :0.08477   Mean   :0.00986
#  3rd Qu.:0.4400   3rd Qu.:0.31250   3rd Qu.:0.10000   3rd Qu.:0.00000
#  Max.   :1.0000   Max.   :1.00000   Max.   :1.00000   Max.   :1.00000
#  NA's   :298      NA's   :298       NA's   :298       NA's   :298
#  part_mention_haute score_mention
#  Min.   :0.00000    Min.   :0.000
#  1st Qu.:0.00000    1st Qu.:0.600
#  Median :0.03279    Median :0.900
#  Mean   :0.09464    Mean   :1.035
#  3rd Qu.:0.10526    3rd Qu.:1.333
#  Max.   :1.00000    Max.   :4.000
#  NA's   :298
#  X..d.admis.néo.bacheliers.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies.
#  Min.   :  0.00
#  1st Qu.: 64.00
#  Median : 83.00
#  Mean   : 75.41
#  3rd Qu.: 95.00
#  Max.   :100.00
#
#  X..d.admis.néo.bacheliers.généraux X..d.admis.néo.bacheliers.technologiques
#  Min.   :  0.00                     Min.   :  0.00
#  1st Qu.: 12.00                     1st Qu.:  0.00
#  Median : 48.00                     Median : 20.00
#  Mean   : 50.04                     Mean   : 24.41
#  3rd Qu.: 90.00                     3rd Qu.: 40.00
#  Max.   :100.00                     Max.   :100.00
#
#  X..d.admis.néo.bacheliers.professionnels log_candidats      log_admis
#  Min.   :  0.00                           Min.   :0.6931   Min.   :0.000
#  1st Qu.:  0.00                           1st Qu.:5.0814   1st Qu.:2.708
#  Median : 10.00                           Median :5.9558   Median :3.258
#  Mean   : 23.45                           Mean   :5.9996   Mean   :3.291
#  3rd Qu.: 43.00                           3rd Qu.:6.9246   3rd Qu.:3.850
#  Max.   :100.00                           Max.   :9.8733   Max.   :7.691
#
#   log_capacite
#  Min.   :0.000
#  1st Qu.:2.944
#  Median :3.434
#  Mean   :3.536
#  3rd Qu.:3.932
#  Max.   :8.132

# %% [markdown]
# Mais il y a pas mal de var NA pour certaines valeurs dans les data, donc on les enlève où on leur donne une valuer moyenne/ nule si normalisé

# %%
#gestions des NA's : remplacement par la médiane
data_GPS <- data_features_core %>%
  mutate(across(where(is.numeric), 
                ~ ifelse(is.na(.), median(., na.rm = TRUE), .)))

# %%
glimpse(data_features_core)
glimpse(select(data_features_core, where(is.numeric)))
# Out:
# Rows: 14,252
# Columns: 32
# $ Établissement                                                                          <fct> …
# $ Statut.Etablissement                                                                   <fct> …
# $ Filière.de.formation                                                                   <fct> …
# $ Filière.de.formation.très.agrégée                                                      <fct> …
# $ Région.de.l.établissement                                                              <fct> …
# $ Académie.de.l.établissement                                                            <fct> …
# $ Coordonnées.GPS.de.la.formation                                                        <fct> …
# $ Sélectivité                                                                            <fct> …
# $ Capacité.de.l.établissement.par.formation                                              <dbl> …
# $ Effectif.total.admis.2phases                                                           <dbl> …
# $ Effectif.total.candidats.2phases                                                       <dbl> …
# $ Pourcentage.boursiers.candidats                                                        <dbl> …
# $ Pourcentage.boursiers.admis                                                            <dbl> …
# $ pct_filles_admises                                                                     <dbl> …
# $ pct_garcons_admis                                                                      <dbl> …
# $ pression_candidature                                                                   <dbl> …
# $ taux_admission                                                                         <dbl> …
# $ taux_remplissage                                                                       <dbl> …
# $ taux_acces_num                                                                         <dbl> …
# $ part_mention_ab                                                                        <dbl> …
# $ part_mention_b                                                                         <dbl> …
# $ part_mention_tb                                                                        <dbl> …
# $ part_mention_tb_fel                                                                    <dbl> …
# $ part_mention_haute                                                                     <dbl> …
# $ score_mention                                                                          <dbl> …
# $ X..d.admis.néo.bacheliers.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies. <dbl> …
# $ X..d.admis.néo.bacheliers.généraux                                                     <dbl> …
# $ X..d.admis.néo.bacheliers.technologiques                                               <dbl> …
# $ X..d.admis.néo.bacheliers.professionnels                                               <dbl> …
# $ log_candidats                                                                          <dbl> …
# $ log_admis                                                                              <dbl> …
# $ log_capacite                                                                           <dbl> …
# Rows: 14,252
# Columns: 24
# $ Capacité.de.l.établissement.par.formation                                              <dbl> …
# $ Effectif.total.admis.2phases                                                           <dbl> …
# $ Effectif.total.candidats.2phases                                                       <dbl> …
# $ Pourcentage.boursiers.candidats                                                        <dbl> …
# $ Pourcentage.boursiers.admis                                                            <dbl> …
# $ pct_filles_admises                                                                     <dbl> …
# $ pct_garcons_admis                                                                      <dbl> …
# $ pression_candidature                                                                   <dbl> …
# $ taux_admission                                                                         <dbl> …
# $ taux_remplissage                                                                       <dbl> …
# $ taux_acces_num                                                                         <dbl> …
# $ part_mention_ab                                                                        <dbl> …
# $ part_mention_b                                                                         <dbl> …
# $ part_mention_tb                                                                        <dbl> …
# $ part_mention_tb_fel                                                                    <dbl> …
# $ part_mention_haute                                                                     <dbl> …
# $ score_mention                                                                          <dbl> …
# $ X..d.admis.néo.bacheliers.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies. <dbl> …
# $ X..d.admis.néo.bacheliers.généraux                                                     <dbl> …
# $ X..d.admis.néo.bacheliers.technologiques                                               <dbl> …
# $ X..d.admis.néo.bacheliers.professionnels                                               <dbl> …
# $ log_candidats                                                                          <dbl> …
# $ log_admis                                                                              <dbl> …
# $ log_capacite                                                                           <dbl> …

# %% [markdown]
# On sépare mainetant les variables qualitatives des quantitatives pour la PCA et la MCA

# %%
#séparation des var quali et quanti
var_quanti <- names(data_features_core)[sapply(data_features_core, is.numeric)]
var_quali  <- names(data_features_core)[sapply(data_features_core, is.factor)]

# Vérifier
var_quanti
var_quali
# Out:
#  [1] "Capacité.de.l.établissement.par.formation"
#  [2] "Effectif.total.admis.2phases"
#  [3] "Effectif.total.candidats.2phases"
#  [4] "Pourcentage.boursiers.candidats"
#  [5] "Pourcentage.boursiers.admis"
#  [6] "pct_filles_admises"
#  [7] "pct_garcons_admis"
#  [8] "pression_candidature"
#  [9] "taux_admission"
# [10] "taux_remplissage"
# [11] "taux_acces_num"
# [12] "part_mention_ab"
# [13] "part_mention_b"
# [14] "part_mention_tb"
# [15] "part_mention_tb_fel"
# [16] "part_mention_haute"
# [17] "score_mention"
# [18] "X..d.admis.néo.bacheliers.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies."
# [19] "X..d.admis.néo.bacheliers.généraux"
# [20] "X..d.admis.néo.bacheliers.technologiques"
# [21] "X..d.admis.néo.bacheliers.professionnels"
# [22] "log_candidats"
# [23] "log_admis"
# [24] "log_capacite"
# [1] "Établissement"                     "Statut.Etablissement"
# [3] "Filière.de.formation"              "Filière.de.formation.très.agrégée"
# [5] "Région.de.l.établissement"         "Académie.de.l.établissement"
# [7] "Coordonnées.GPS.de.la.formation"   "Sélectivité"

# %%
saveRDS(data_GPS, file = "../processed/data_GPS.rds")
