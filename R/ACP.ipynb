# %%
source("../R/shared_data.R")
data_features_core <- load_analysis_data()
var_quanti <- names(data_features_core)[sapply(data_features_core, is.numeric)]

library(FactoMineR)
library(factoextra)

# # ACP centrée-réduite (scale.unit = TRUE par défaut)
# acp <- PCA(data_features_core %>% select(all_of(var_quanti)) %>%
#              select(-c("log_candidats", "log_admis","log_capacite")),,
#            scale.unit = TRUE,
#            graph = FALSE)
acp <- readRDS("acp.rds")
# Out:
# Warning message:
# "le package 'tidyverse' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'ggplot2' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'tibble' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'tidyr' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'readr' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'purrr' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'dplyr' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'stringr' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'forcats' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'lubridate' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'FactoMineR' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'factoextra' a été compilé avec la version R 4.4.3"
# Welcome! Want to learn more? See two factoextra-related books at https://goo.gl/ve3WBa

# %%
glimpse(data_features_core)
# Out:
# Rows: 14,252
# Columns: 31
# $ Établissement                                                                          <fct> …
# $ Statut.Etablissement                                                                   <fct> …
# $ Filière.de.formation                                                                   <fct> …
# $ Filière.de.formation.très.agrégée                                                      <fct> …
# $ Région.de.l.établissement                                                              <fct> …
# $ Académie.de.l.établissement                                                            <fct> …
# $ Sélectivité                                                                            <fct> …
# $ Capacité.de.l.établissement.par.formation                                              <dbl> …
# $ Effectif.total.admis.2phases                                                           <dbl> …
# $ Effectif.total.candidats.2phases                                                       <dbl> …
# $ Pourcentage.boursiers.candidats                                                        <dbl> …
# $ Pourcentage.boursiers.admis                                                            <dbl> …
# $ pct_filles_admises                                                                     <dbl> …
# $ pct_garcons_admis                                                                      <dbl> …
# $ pression_candidature                                                                   <dbl> …
# $ taux_admission                                                                         <dbl> …
# $ taux_remplissage                                                                       <dbl> …
# $ taux_acces_num                                                                         <dbl> …
# $ part_mention_ab                                                                        <dbl> …
# $ part_mention_b                                                                         <dbl> …
# $ part_mention_tb                                                                        <dbl> …
# $ part_mention_tb_fel                                                                    <dbl> …
# $ part_mention_haute                                                                     <dbl> …
# $ score_mention                                                                          <dbl> …
# $ X..d.admis.néo.bacheliers.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies. <dbl> …
# $ X..d.admis.néo.bacheliers.généraux                                                     <dbl> …
# $ X..d.admis.néo.bacheliers.technologiques                                               <dbl> …
# $ X..d.admis.néo.bacheliers.professionnels                                               <dbl> …
# $ log_candidats                                                                          <dbl> …
# $ log_admis                                                                              <dbl> …
# $ log_capacite                                                                           <dbl> …

# %%
summary(select(data_features_core, Filière.de.formation.très.agrégée))
levels(data_features_core$Filière.de.formation.très.agrégée)
# Out:
#  Filière.de.formation.très.agrégée
#  BTS              :5351
#  Licence          :3052
#  Autre formation  :1815
#  CPGE             : 986
#  BUT              : 820
#  Ecole d'Ingénieur: 585
#  (Other)          :1643
#  [1] "Autre formation"   "BTS"               "BUT"
#  [4] "CPGE"              "Ecole d'Ingénieur" "Ecole de Commerce"
#  [7] "EFTS"              "IFSI"              "Licence"
# [10] "Licence_Las"       "PASS"

# %%
# Variance expliquée par axe
fviz_eig(acp, addlabels = TRUE, ylim = c(0, 50))
# Out:
# Warning message in geom_bar(stat = "identity", fill = barfill, color = barcolor, :
# "Ignoring empty aesthetic: `width`."
# plot without title

# %%
library(knitr)

contrib_var <- as.data.frame(acp$var$contrib)
kable(round(contrib_var, 2), caption = "Contributions des variables aux axes factoriels (%)")
# Out:
# Warning message:
# "le package 'knitr' a été compilé avec la version R 4.4.3"
# Table: Contributions des variables aux axes factoriels (%)
#
# |                                                                                       | Dim.1| Dim.2| Dim.3| Dim.4| Dim.5|
# |:--------------------------------------------------------------------------------------|-----:|-----:|-----:|-----:|-----:|
# |Capacité.de.l.établissement.par.formation                                              |  0.72| 15.28|  5.37| 11.63|  2.09|
# |Effectif.total.admis.2phases                                                           |  1.46| 18.46|  3.75| 14.06|  1.18|
# |Effectif.total.candidats.2phases                                                       |  5.45|  8.18|  0.79|  9.50|  2.67|
# |Pourcentage.boursiers.candidats                                                        |  3.80|  2.18| 16.41|  1.05|  4.02|
# |Pourcentage.boursiers.admis                                                            |  2.97|  1.55| 12.43|  1.41|  4.48|
# |pct_filles_admises                                                                     |  1.61| 13.45|  1.94| 23.63|  5.47|
# |pct_garcons_admis                                                                      |  1.61| 13.45|  1.94| 23.63|  5.47|
# |pression_candidature                                                                   |  3.80|  0.09|  7.43|  0.27| 10.92|
# |taux_admission                                                                         |  2.91|  0.05|  7.18|  0.13| 18.41|
# |taux_remplissage                                                                       |  1.70|  3.18|  4.56|  1.95|  0.02|
# |taux_acces_num                                                                         |  4.15|  0.18| 16.10|  0.16|  4.80|
# |part_mention_ab                                                                        |  2.37|  3.53|  0.15|  0.48|  9.15|
# |part_mention_b                                                                         |  5.25|  0.13|  0.00|  0.30|  2.87|
# |part_mention_tb                                                                        | 11.51|  4.78|  0.66|  0.47|  5.66|
# |part_mention_tb_fel                                                                    |  4.48|  2.80|  0.61|  0.85|  8.75|
# |part_mention_haute                                                                     | 12.16|  5.45|  0.82|  0.70|  8.13|
# |score_mention                                                                          | 13.83|  2.37|  0.66|  0.26|  0.76|
# |X..d.admis.néo.bacheliers.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies. |  2.13|  0.69|  2.88|  6.01|  0.28|
# |X..d.admis.néo.bacheliers.généraux                                                     |  9.07|  1.42|  7.02|  0.57|  0.66|
# |X..d.admis.néo.bacheliers.technologiques                                               |  2.98|  0.15|  4.96|  0.00|  0.37|
# |X..d.admis.néo.bacheliers.professionnels                                               |  6.03|  2.64|  4.35|  2.95|  3.84|

# %%
# Cercle des corrélations (variables)
fviz_pca_var(acp,
             col.var = "cos2",        # colorier selon qualité de représentation
             gradient.cols = c("grey", "blue", "red"),
             repel = TRUE)            # éviter le chevauchement des labels
# Out:
# Warning message:
# "Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead.
# ℹ The deprecated feature was likely used in the ggpubr package.
#   Please report the issue at <https://github.com/kassambara/ggpubr/issues>."
# Warning message:
# "`aes_string()` was deprecated in ggplot2 3.0.0.
# ℹ Please use tidy evaluation idioms with `aes()`.
# ℹ See also `vignette("ggplot2-in-packages")` for more information.
# ℹ The deprecated feature was likely used in the factoextra package.
#   Please report the issue at <https://github.com/kassambara/factoextra/issues>."
# plot without title

# %% [markdown]
# Interprétation : La première dim semble représenter les fillières très sélectives, adressées aux bacs généraux, avec un faible taux d'admission et avec des candidats ayant reçu une bonne mention au bac.

# %%
#projection des variables selon les axes 1 et 3

fviz_pca_var(acp, axes = c(1, 3), 
             col.var = "cos2",        # colorier selon qualité de représentation
             gradient.cols = c("grey", "blue", "red"),
             repel = TRUE)
# Out:
# plot without title

# %%
# Projection des individus
fviz_pca_ind(acp,
             col.ind = "cos2",
             gradient.cols = c("grey", "blue", "red"),
             repel = FALSE,
             label="none")
# Out:
# plot without title

# %% [markdown]
# Test de visualisation des individus dans différents axes selon plusieurs variables.

# %%
fviz_pca_ind(acp,
             col.ind = data_features_core$Sélectivité,  # variable quali
             palette = "jco",          # palette de couleurs
             addEllipses = FALSE,       # ellipses de confiance par groupe
             legend.title = "Sélectivité",
             label = "none")
# Out:
# Ignoring unknown labels:
# • fill : "Sélectivité"
# • linetype : "Sélectivité"
# plot without title

# %% [markdown]
# Axe 1 semble séparer formations sélectives des non-sélectives

# %%
fviz_pca_ind(acp,
             col.ind = data_features_core$Statut.Etablissement,  # variable quali
             palette = "jco",          # palette de couleurs
             addEllipses = FALSE,       # ellipses de confiance par groupe
             legend.title = "Statut de l'établissement",
             label = "none")
# Out:
# Ignoring unknown labels:
# • fill : "Statut de l'établissement"
# • linetype : "Statut de l'établissement"
# plot without title

# %%
fviz_pca_ind(acp,
             col.ind = data_features_core$log_candidats,  # variable quanti
             gradient.cols = c("blue", "white", "red"),
             legend.title = "Nombre de candidats (log)",
             label = "none")
# Out:
# Ignoring unknown labels:
# • fill : "Nombre de candidats (log)"
# • linetype : "Nombre de candidats (log)"
# • shape : "Nombre de candidats (log)"
# plot without title

# %% [markdown]
# L'axe 2 semble séparer les gros établissements des petits.

# %%
fviz_pca_ind(acp,
             col.ind = data_features_core$part_mention_haute,  # variable quanti
             gradient.cols = c("blue", "white", "red"),
             legend.title = "Part de mentions\nTB et plus",
             label = "none")
# Out:
# Ignoring unknown labels:
# • fill : "Part de mentions TB et plus"
# • linetype : "Part de mentions TB et plus"
# • shape : "Part de mentions TB et plus"
# plot without title

# %% [markdown]
# L'axe 1 et l'axe 2 permettent de déceler des clusters liés au type de mentions.

# %%
fviz_pca_ind(acp,
             col.ind = data_features_core$X..d.admis.néo.bacheliers.généraux,  # variable quanti
             gradient.cols = c("blue", "white", "red"),
             legend.title = "Part de bacs généraux",
             label = "none")
# Out:
# Ignoring unknown labels:
# • fill : "Part de bacs généraux"
# • linetype : "Part de bacs généraux"
# • shape : "Part de bacs généraux"
# plot without title

# %%
# Biplot (individus + variables)
fviz_pca_biplot(acp, repel = TRUE)

# Résumé numérique
#summary(acp)

saveRDS(acp, "acp.rds")
# Out:
# plot without title
