# %%
source("../R/shared_data.R")
library(MASS)      # pour lda()
library(tidyverse)
library(ggplot2)
select <- dplyr::select  # ← règle le conflit MASS vs dplyr

df <- load_analysis_data()
# Out:
# Warning message:
# "le package 'tidyverse' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'ggplot2' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'tibble' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'tidyr' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'readr' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'purrr' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'dplyr' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'stringr' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'forcats' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'lubridate' a été compilé avec la version R 4.4.3"
# Warning message:
# "le package 'MASS' a été compilé avec la version R 4.4.3"
#
# Attachement du package : 'MASS'
#
#
# L'objet suivant est masqué depuis 'package:dplyr':
#
#     select

# %%
var_quanti <- names(df)[sapply(df, is.numeric)]

df_lda <- df %>%
  select(all_of(var_quanti), "Filière.de.formation.très.agrégée") %>%
  rename(filiere = "Filière.de.formation.très.agrégée")

# %% [markdown]
# Pour plus de simplicité, on merge certaines formations similaires

# %%
df_lda %>% count(filiere, sort = TRUE)
# Out:
#    filiere           n
# 1  BTS               5351
# 2  Licence           3052
# 3  Autre formation   1815
# 4  CPGE               986
# 5  BUT                820
# 6  Ecole d'Ingénieur  585
# 7  Licence_Las        513
# 8  IFSI               344
# 9  PASS               287
# 10 Ecole de Commerce  256
# 11 EFTS               243

# %% [markdown]
# On peut éventuellement recoder la variable pour simplifier, on le fait pas pour le moment

# %%
# library(forcats)

# df_lda <- df_lda %>%
#   mutate(filiere = fct_recode(filiere,
#     "Licence"  = "Licence",   # merge ces deux ensemble
#     "Licence"    = "Licence générale",
#     "Licence"    = "Licence professionnelle",   # merge
#     "CPGE"       = "Classe préparatoire",
#     ...
#   ))

# %%
modele_lda <- lda(filiere ~ ., data = df_lda)
modele_lda
# Out:
# Warning message in lda.default(x, grouping, ...):
# "les variables sont colinéaires"
# Call:
# lda(filiere ~ ., data = df_lda)
#
# Prior probabilities of groups:
#   Autre formation               BTS               BUT              CPGE
#        0.12735055        0.37545608        0.05753578        0.06918327
# Ecole d'Ingénieur Ecole de Commerce              EFTS              IFSI
#        0.04104687        0.01796239        0.01705024        0.02413696
#           Licence       Licence_Las              PASS
#        0.21414538        0.03599495        0.02013752
#
# Group means:
#                   Capacité.de.l.établissement.par.formation
# Autre formation                                    27.45675
# BTS                                                31.58905
# BUT                                                72.26220
# CPGE                                               47.44828
# Ecole d'Ingénieur                                  44.98803
# Ecole de Commerce                                  89.32812
# EFTS                                               31.65844
# IFSI                                               89.57267
# Licence                                           101.27457
# Licence_Las                                        40.96881
# PASS                                               92.84321
#                   Effectif.total.admis.2phases Effectif.total.candidats.2phases
# Autre formation                       23.00771                         476.0601
# BTS                                   21.88114                         416.2439
# BUT                                   69.17927                        1625.2366
# CPGE                                  42.68357                        1318.7302
# Ecole d'Ingénieur                     35.96923                        1637.3145
# Ecole de Commerce                     60.16797                        1515.4922
# EFTS                                  28.86420                         196.9383
# IFSI                                  88.87209                        4201.0029
# Licence                               92.44528                        1088.2231
# Licence_Las                           39.83431                         982.8967
# PASS                                  92.28223                        3880.7456
#                   Pourcentage.boursiers.candidats Pourcentage.boursiers.admis
# Autre formation                         20.322665                   20.325644
# BTS                                     26.342756                   28.406777
# BUT                                     18.785453                   19.322932
# CPGE                                    11.480940                   11.245751
# Ecole d'Ingénieur                        9.544239                   10.784787
# Ecole de Commerce                        7.585096                    8.829841
# EFTS                                    18.119807                   16.832567
# IFSI                                    24.858124                   23.047690
# Licence                                 20.264982                   22.593794
# Licence_Las                             21.423393                   25.154201
# PASS                                    15.987512                   18.007236
#                   pct_filles_admises pct_garcons_admis pression_candidature
# Autre formation            0.5407240         0.4592760            18.372246
# BTS                        0.4196007         0.5803993            15.413428
# BUT                        0.4006574         0.5993426            21.823644
# CPGE                       0.4090236         0.5909764            28.549169
# Ecole d'Ingénieur          0.3027175         0.6972825            40.754019
# Ecole de Commerce          0.4560973         0.5439027            28.425734
# EFTS                       0.8768491         0.1231509             6.940539
# IFSI                       0.8571771         0.1428229            57.223912
# Licence                    0.6301511         0.3698489            14.758622
# Licence_Las                0.6647676         0.3352324            31.844428
# PASS                       0.6863554         0.3136446            87.079263
#                   taux_admission taux_remplissage taux_acces_num
# Autre formation       0.10040591        0.8042455      0.4812672
# BTS                   0.08991864        0.8063373      0.5946907
# BUT                   0.06362789        0.9394455      0.4819024
# CPGE                  0.04738023        0.8774330      0.5995335
# Ecole d'Ingénieur     0.04591823        0.6282010      0.6351966
# Ecole de Commerce     0.10358489        0.5570922      0.5382422
# EFTS                  0.19632823        0.8747049      0.4760494
# IFSI                  0.02663112        0.9923120      0.4637791
# Licence               0.10947427        0.8717824      0.6898657
# Licence_Las           0.06168037        0.9515831      0.5158090
# PASS                  0.03225624        0.9971484      0.3789547
#                   part_mention_ab part_mention_b part_mention_tb
# Autre formation         0.3311183      0.2323511      0.10420700
# BTS                     0.3512934      0.1569419      0.03594038
# BUT                     0.4125356      0.2116338      0.04066233
# CPGE                    0.2252183      0.3733138      0.28441601
# Ecole d'Ingénieur       0.3185651      0.3098226      0.12430258
# Ecole de Commerce       0.3505809      0.1684861      0.03919040
# EFTS                    0.3518648      0.1968471      0.05316537
# IFSI                    0.3954595      0.2239971      0.05323398
# Licence                 0.3128011      0.2228250      0.09217691
# Licence_Las             0.3576952      0.2401702      0.07666259
# PASS                    0.2588227      0.3442518      0.21546432
#                   part_mention_tb_fel part_mention_haute score_mention
# Autre formation          0.0153408542         0.11972451     1.1287060
# BTS                      0.0020907367         0.03805634     0.7754917
# BUT                      0.0023710525         0.04303338     0.9672745
# CPGE                     0.0446192502         0.32903526     2.0035709
# Ecole d'Ingénieur        0.0110162039         0.13587842     1.2249865
# Ecole de Commerce        0.0008507843         0.04013347     0.7870570
# EFTS                     0.0050483585         0.05844985     0.8703165
# IFSI                     0.0028603796         0.05609436     1.0145971
# Licence                  0.0099259137         0.10214374     1.0651662
# Licence_Las              0.0065618928         0.08325080     1.0881485
# PASS                     0.0352203751         0.25069645     1.7318649
#                   X..d.admis.néo.bacheliers.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies.
# Autre formation                                                                                 61.69366
# BTS                                                                                             84.97776
# BUT                                                                                             74.57683
# CPGE                                                                                            73.69980
# Ecole d'Ingénieur                                                                               51.39145
# Ecole de Commerce                                                                               61.23047
# EFTS                                                                                            76.02058
# IFSI                                                                                            81.54942
# Licence                                                                                         71.25098
# Licence_Las                                                                                     78.67836
# PASS                                                                                            84.34146
#                   X..d.admis.néo.bacheliers.généraux
# Autre formation                             47.82755
# BTS                                         17.25416
# BUT                                         54.73415
# CPGE                                        88.66633
# Ecole d'Ingénieur                           65.08205
# Ecole de Commerce                           76.17969
# EFTS                                        34.31276
# IFSI                                        40.18605
# Licence                                     81.67202
# Licence_Las                                 87.99025
# PASS                                        96.00348
#                   X..d.admis.néo.bacheliers.technologiques
# Autre formation                                  21.449587
# BTS                                              35.423659
# BUT                                              42.628049
# CPGE                                             10.204868
# Ecole d'Ingénieur                                17.888889
# Ecole de Commerce                                18.449219
# EFTS                                             34.325103
# IFSI                                             37.936047
# Licence                                          10.818152
# Licence_Las                                       7.777778
# PASS                                              2.620209
#                   X..d.admis.néo.bacheliers.professionnels log_candidats
# Autre formation                                 25.4633609      5.280816
# BTS                                             46.5427023      5.543524
# BUT                                              2.6243902      6.952189
# CPGE                                             1.1288032      6.813483
# Ecole d'Ingénieur                                0.4478632      6.022719
# Ecole de Commerce                                2.6171875      6.250344
# EFTS                                            24.3127572      4.881035
# IFSI                                            21.8459302      8.163714
# Licence                                          6.2873526      6.300484
# Licence_Las                                      3.4561404      6.293307
# PASS                                             1.0383275      7.888101
#                   log_admis log_capacite
# Autre formation    2.710841     3.018486
# BTS                2.971101     3.231428
# BUT                4.049946     4.128198
# CPGE               3.575133     3.741227
# Ecole d'Ingénieur  2.543853     3.176104
# Ecole de Commerce  3.230908     4.046114
# EFTS               3.061955     3.274390
# IFSI               4.355696     4.364905
# Licence            3.890516     4.102106
# Licence_Las        3.239765     3.301490
# PASS               4.000372     4.008473
#
# Coefficients of linear discriminants:
#                                                                                                  LD1
# Capacité.de.l.établissement.par.formation                                              -1.344958e-03
# Effectif.total.admis.2phases                                                            3.650966e-03
# Effectif.total.candidats.2phases                                                       -2.065614e-05
# Pourcentage.boursiers.candidats                                                         3.661185e-03
# Pourcentage.boursiers.admis                                                             8.424066e-03
# pct_filles_admises                                                                      3.460729e-02
# pct_garcons_admis                                                                      -3.460729e-02
# pression_candidature                                                                    1.133244e-03
# taux_admission                                                                          2.543876e+00
# taux_remplissage                                                                        5.302525e-01
# taux_acces_num                                                                          1.757684e+00
# part_mention_ab                                                                         1.306622e+01
# part_mention_b                                                                          2.679080e+01
# part_mention_tb                                                                         2.058514e+01
# part_mention_tb_fel                                                                     3.310787e+01
# part_mention_haute                                                                      1.944585e+01
# score_mention                                                                          -1.274532e+01
# X..d.admis.néo.bacheliers.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies.  1.025944e-03
# X..d.admis.néo.bacheliers.généraux                                                      1.128176e-01
# X..d.admis.néo.bacheliers.technologiques                                                7.824180e-02
# X..d.admis.néo.bacheliers.professionnels                                                6.547727e-02
# log_candidats                                                                           1.925457e-01
# log_admis                                                                              -4.625386e-01
# log_capacite                                                                            3.078475e-01
#                                                                                                  LD2
# Capacité.de.l.établissement.par.formation                                              -1.434077e-03
# Effectif.total.admis.2phases                                                            5.411862e-03
# Effectif.total.candidats.2phases                                                       -1.625449e-04
# Pourcentage.boursiers.candidats                                                         6.032108e-03
# Pourcentage.boursiers.admis                                                             3.082906e-03
# pct_filles_admises                                                                      8.743187e-01
# pct_garcons_admis                                                                      -8.743187e-01
# pression_candidature                                                                    5.612818e-03
# taux_admission                                                                          5.309350e+00
# taux_remplissage                                                                        9.199010e-01
# taux_acces_num                                                                         -2.813440e+00
# part_mention_ab                                                                        -6.738025e+00
# part_mention_b                                                                         -1.357940e+01
# part_mention_tb                                                                        -1.059065e+01
# part_mention_tb_fel                                                                    -1.701156e+01
# part_mention_haute                                                                     -9.949009e+00
# score_mention                                                                           5.699818e+00
# X..d.admis.néo.bacheliers.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies. -1.070714e-02
# X..d.admis.néo.bacheliers.généraux                                                     -2.078336e-02
# X..d.admis.néo.bacheliers.technologiques                                               -3.925997e-02
# X..d.admis.néo.bacheliers.professionnels                                               -2.976197e-02
# log_candidats                                                                          -8.318930e-01
# log_admis                                                                              -3.632624e-01
# log_capacite                                                                            9.231943e-01
#                                                                                                  LD3
# Capacité.de.l.établissement.par.formation                                              -0.0011144766
# Effectif.total.admis.2phases                                                           -0.0040884531
# Effectif.total.candidats.2phases                                                        0.0004786239
# Pourcentage.boursiers.candidats                                                         0.0025505691
# Pourcentage.boursiers.admis                                                            -0.0031476153
# pct_filles_admises                                                                      0.7760520807
# pct_garcons_admis                                                                      -0.7760520807
# pression_candidature                                                                    0.0066207424
# taux_admission                                                                         -2.4725400633
# taux_remplissage                                                                        1.3858472836
# taux_acces_num                                                                          0.5474276237
# part_mention_ab                                                                        -2.2134601292
# part_mention_b                                                                         -5.3114697070
# part_mention_tb                                                                        -4.5923723758
# part_mention_tb_fel                                                                    -6.6906193085
# part_mention_haute                                                                     -4.2095695990
# score_mention                                                                           1.9448814599
# X..d.admis.néo.bacheliers.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies.  0.0043959406
# X..d.admis.néo.bacheliers.généraux                                                     -0.0201005711
# X..d.admis.néo.bacheliers.technologiques                                               -0.0133425209
# X..d.admis.néo.bacheliers.professionnels                                               -0.0141788002
# log_candidats                                                                          -0.1318451417
# log_admis                                                                              -0.1066144281
# log_capacite                                                                            0.9081686480
#                                                                                                  LD4
# Capacité.de.l.établissement.par.formation                                              -0.0005548462
# Effectif.total.admis.2phases                                                           -0.0024594571
# Effectif.total.candidats.2phases                                                        0.0004240259
# Pourcentage.boursiers.candidats                                                        -0.0357095884
# Pourcentage.boursiers.admis                                                            -0.0066027620
# pct_filles_admises                                                                     -0.2118327527
# pct_garcons_admis                                                                       0.2118327527
# pression_candidature                                                                   -0.0024869923
# taux_admission                                                                         11.3637906139
# taux_remplissage                                                                       -1.1539339448
# taux_acces_num                                                                         -2.4804783603
# part_mention_ab                                                                        -0.8816182758
# part_mention_b                                                                         -2.9981475963
# part_mention_tb                                                                        -3.2484661822
# part_mention_tb_fel                                                                    -5.0438088648
# part_mention_haute                                                                     -2.9896625343
# score_mention                                                                           1.2798079146
# X..d.admis.néo.bacheliers.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies. -0.0125639217
# X..d.admis.néo.bacheliers.généraux                                                     -0.0125393125
# X..d.admis.néo.bacheliers.technologiques                                               -0.0015499030
# X..d.admis.néo.bacheliers.professionnels                                               -0.0209742367
# log_candidats                                                                           0.4220987941
# log_admis                                                                              -0.8337036742
# log_capacite                                                                            0.0298449567
#                                                                                                  LD5
# Capacité.de.l.établissement.par.formation                                               0.0022337318
# Effectif.total.admis.2phases                                                           -0.0020034628
# Effectif.total.candidats.2phases                                                        0.0003170385
# Pourcentage.boursiers.candidats                                                         0.0018759275
# Pourcentage.boursiers.admis                                                            -0.0042769918
# pct_filles_admises                                                                      1.0088300888
# pct_garcons_admis                                                                      -1.0088300888
# pression_candidature                                                                    0.0038211249
# taux_admission                                                                          2.1904384485
# taux_remplissage                                                                        0.5504332151
# taux_acces_num                                                                          0.4567914848
# part_mention_ab                                                                         0.0679817084
# part_mention_b                                                                          1.6323775671
# part_mention_tb                                                                         1.4591298790
# part_mention_tb_fel                                                                     2.3609592823
# part_mention_haute                                                                      1.3407945048
# score_mention                                                                          -0.3765770018
# X..d.admis.néo.bacheliers.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies.  0.0130374639
# X..d.admis.néo.bacheliers.généraux                                                     -0.0085154344
# X..d.admis.néo.bacheliers.technologiques                                               -0.0214386464
# X..d.admis.néo.bacheliers.professionnels                                                0.0026906635
# log_candidats                                                                           0.0037609079
# log_admis                                                                              -0.0535175397
# log_capacite                                                                           -0.9331690667
#                                                                                                  LD6
# Capacité.de.l.établissement.par.formation                                               1.104703e-03
# Effectif.total.admis.2phases                                                            6.279031e-03
# Effectif.total.candidats.2phases                                                        5.186631e-05
# Pourcentage.boursiers.candidats                                                         1.222158e-02
# Pourcentage.boursiers.admis                                                             9.401324e-03
# pct_filles_admises                                                                     -3.225162e-01
# pct_garcons_admis                                                                       3.225162e-01
# pression_candidature                                                                    8.787765e-03
# taux_admission                                                                         -6.359811e+00
# taux_remplissage                                                                       -8.349187e-01
# taux_acces_num                                                                          1.464548e+00
# part_mention_ab                                                                         1.051237e+01
# part_mention_b                                                                          2.168654e+01
# part_mention_tb                                                                         1.610457e+01
# part_mention_tb_fel                                                                     2.655986e+01
# part_mention_haute                                                                      1.537883e+01
# score_mention                                                                          -1.156748e+01
# X..d.admis.néo.bacheliers.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies. -1.040102e-02
# X..d.admis.néo.bacheliers.généraux                                                      1.038402e-01
# X..d.admis.néo.bacheliers.technologiques                                                8.480273e-02
# X..d.admis.néo.bacheliers.professionnels                                                1.029000e-01
# log_candidats                                                                           1.240875e-02
# log_admis                                                                              -1.622844e-01
# log_capacite                                                                           -5.011686e-01
#                                                                                                  LD7
# Capacité.de.l.établissement.par.formation                                               1.473910e-03
# Effectif.total.admis.2phases                                                           -2.473771e-03
# Effectif.total.candidats.2phases                                                        1.520004e-04
# Pourcentage.boursiers.candidats                                                         2.327483e-02
# Pourcentage.boursiers.admis                                                             8.544223e-03
# pct_filles_admises                                                                     -3.311899e-01
# pct_garcons_admis                                                                       3.311899e-01
# pression_candidature                                                                    2.736533e-03
# taux_admission                                                                         -1.148173e+01
# taux_remplissage                                                                        6.795934e-01
# taux_acces_num                                                                         -8.229198e-01
# part_mention_ab                                                                         1.027650e+01
# part_mention_b                                                                          1.729943e+01
# part_mention_tb                                                                         1.221888e+01
# part_mention_tb_fel                                                                     2.192506e+01
# part_mention_haute                                                                      1.183087e+01
# score_mention                                                                          -8.410305e+00
# X..d.admis.néo.bacheliers.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies. -4.035869e-03
# X..d.admis.néo.bacheliers.généraux                                                      6.722842e-02
# X..d.admis.néo.bacheliers.technologiques                                                6.413047e-02
# X..d.admis.néo.bacheliers.professionnels                                                4.607005e-02
# log_candidats                                                                          -1.068708e+00
# log_admis                                                                               1.754416e+00
# log_capacite                                                                           -1.355662e+00
#                                                                                                  LD8
# Capacité.de.l.établissement.par.formation                                               0.0011229027
# Effectif.total.admis.2phases                                                           -0.0025567130
# Effectif.total.candidats.2phases                                                       -0.0002488732
# Pourcentage.boursiers.candidats                                                        -0.0342504420
# Pourcentage.boursiers.admis                                                             0.0087858567
# pct_filles_admises                                                                     -0.3912873946
# pct_garcons_admis                                                                       0.3912873946
# pression_candidature                                                                    0.0149558957
# taux_admission                                                                          0.1597542856
# taux_remplissage                                                                        0.6424165557
# taux_acces_num                                                                         -2.4585085303
# part_mention_ab                                                                         3.2608642178
# part_mention_b                                                                          6.6831487954
# part_mention_tb                                                                         5.5752325383
# part_mention_tb_fel                                                                    10.8566490618
# part_mention_haute                                                                      5.4829709786
# score_mention                                                                          -4.2578648223
# X..d.admis.néo.bacheliers.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies.  0.0235954411
# X..d.admis.néo.bacheliers.généraux                                                      0.0616471666
# X..d.admis.néo.bacheliers.technologiques                                                0.0460730391
# X..d.admis.néo.bacheliers.professionnels                                                0.0541094732
# log_candidats                                                                          -0.1594965430
# log_admis                                                                              -0.8206240958
# log_capacite                                                                            1.1685680878
#                                                                                                  LD9
# Capacité.de.l.établissement.par.formation                                              -2.238724e-03
# Effectif.total.admis.2phases                                                            3.276057e-03
# Effectif.total.candidats.2phases                                                        1.352454e-04
# Pourcentage.boursiers.candidats                                                         2.403048e-02
# Pourcentage.boursiers.admis                                                            -5.501786e-03
# pct_filles_admises                                                                     -5.113015e-01
# pct_garcons_admis                                                                       5.113015e-01
# pression_candidature                                                                    2.855749e-02
# taux_admission                                                                         -1.219759e+01
# taux_remplissage                                                                       -3.208682e-01
# taux_acces_num                                                                         -1.601326e+00
# part_mention_ab                                                                        -4.951729e+00
# part_mention_b                                                                         -9.154420e+00
# part_mention_tb                                                                        -6.472073e+00
# part_mention_tb_fel                                                                    -1.052989e+01
# part_mention_haute                                                                     -6.181638e+00
# score_mention                                                                           4.754751e+00
# X..d.admis.néo.bacheliers.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies. -1.970793e-02
# X..d.admis.néo.bacheliers.généraux                                                     -1.785652e-02
# X..d.admis.néo.bacheliers.technologiques                                               -1.860139e-02
# X..d.admis.néo.bacheliers.professionnels                                               -8.335927e-03
# log_candidats                                                                          -2.020716e+00
# log_admis                                                                               1.317073e+00
# log_capacite                                                                            1.070096e+00
#                                                                                                 LD10
# Capacité.de.l.établissement.par.formation                                               4.215394e-04
# Effectif.total.admis.2phases                                                            3.693942e-03
# Effectif.total.candidats.2phases                                                       -1.345590e-04
# Pourcentage.boursiers.candidats                                                        -1.814558e-02
# Pourcentage.boursiers.admis                                                             8.494129e-03
# pct_filles_admises                                                                     -3.338443e-01
# pct_garcons_admis                                                                       3.338443e-01
# pression_candidature                                                                    2.655765e-02
# taux_admission                                                                         -3.374516e-01
# taux_remplissage                                                                       -9.147193e-01
# taux_acces_num                                                                          2.716426e-01
# part_mention_ab                                                                         1.262018e+01
# part_mention_b                                                                          2.650650e+01
# part_mention_tb                                                                         1.945763e+01
# part_mention_tb_fel                                                                     3.255902e+01
# part_mention_haute                                                                      1.854550e+01
# score_mention                                                                          -1.262585e+01
# X..d.admis.néo.bacheliers.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies.  2.095167e-02
# X..d.admis.néo.bacheliers.généraux                                                      4.063839e-02
# X..d.admis.néo.bacheliers.technologiques                                                5.211460e-02
# X..d.admis.néo.bacheliers.professionnels                                                3.531477e-02
# log_candidats                                                                          -9.542921e-01
# log_admis                                                                               1.824548e+00
# log_capacite                                                                           -8.890032e-01
#
# Proportion of trace:
#    LD1    LD2    LD3    LD4    LD5    LD6    LD7    LD8    LD9   LD10
# 0.5363 0.1404 0.1022 0.0849 0.0534 0.0285 0.0215 0.0152 0.0094 0.0080

# %%
prop_variance <- modele_lda$svd^2 / sum(modele_lda$svd^2)
round(prop_variance * 100, 1)
# Out:
#  [1] 53.6 14.0 10.2  8.5  5.3  2.9  2.2  1.5  0.9  0.8

# %%
predictions <- predict(modele_lda)

df_plot <- data.frame(
  LD1 = predictions$x[, 1],
  LD2 = predictions$x[, 2],
  filiere = df_lda$filiere
)

head(df_plot)
# Out:
#   LD1         LD2        filiere
# 1  1.07024665  1.2454418 Autre formation
# 2 -0.71943873  0.6953160 Licence
# 3 -0.58215372 -0.7914153 IFSI
# 4  2.04917547 -0.7248171 PASS
# 5  2.21122068 -1.3224376 PASS
# 6 -0.01128276  0.1234751 Licence

# %%
ggplot(df_plot, aes(x = LD1, y = LD2, color = filiere)) +
  geom_point(alpha = 0.4, size = 1.5) +
  stat_ellipse(aes(group = filiere), type = "norm", linetype = "dashed") +
  labs(
    title = "LDA — Séparation des filières Parcoursup",
    x = paste0("LD1 (", round(prop_variance[1] * 100, 1), "%)"),
    y = paste0("LD2 (", round(prop_variance[2] * 100, 1), "%)")
  ) +
  theme_minimal()
# Out:
# plot without title

# %%
predictions_class <- predictions$class

table(Réel = df_lda$filiere, Prédit = predictions_class)

# Taux de bonne classification global
mean(predictions_class == df_lda$filiere)
# Out:
#                    Prédit
# Réel               Autre formation  BTS  BUT CPGE Ecole d'Ingénieur
#   Autre formation               556  580   66   87                56
#   BTS                           191 4931   19    2                39
#   BUT                            57   77  493    7                 4
#   CPGE                            7   64   41  710                22
#   Ecole d'Ingénieur              47   40   31   77               196
#   Ecole de Commerce              22    4   18    2                11
#   EFTS                           35   53    0    0                 6
#   IFSI                            2   75   11    0                 0
#   Licence                       121   91   30  239                40
#   Licence_Las                    29   12    5   23                 5
#   PASS                            0    0    0   40                 3
#                    Prédit
# Réel               Ecole de Commerce EFTS IFSI Licence Licence_Las PASS
#   Autre formation                  37   69    7     302          47    8
#   BTS                              14   48   16      82           7    2
#   BUT                               1    1   45     132           3    0
#   CPGE                              0    0    0     113          14   15
#   Ecole d'Ingénieur                46    3   20      71          13   41
#   Ecole de Commerce               116   15    7      56           1    4
#   EFTS                              2  139    0       4           4    0
#   IFSI                              0    0  234      13           2    7
#   Licence                          42    8   22    2276         154   29
#   Licence_Las                       0    0    2     237         172   28
#   PASS                              0    0    6     101          25  112
# [1] 0.6970951

# %% [markdown]
# LDA compliquée à visualiser avec autant de classes : on en retente une en regroupant les modalités par secteur

# %%
library(forcats)

df_lda_simple <- df_lda %>%
  filter(filiere != "Autre formation") %>%
  mutate(filiere = fct_recode(filiere,
    "Santé"  = "PASS",   # merge ces deux ensemble
    "Santé"    = "Licence_Las", 
    "Santé"    = "IFSI",
    "BUT/BTS"       = "BUT", 
    "BUT/BTS"       = "BTS",
    "BUT/BTS"       = "EFTS",
    "Licence"  = "Licence", 
    "Grande école" = "CPGE",
    "Grande école" = "Ecole de Commerce",
    "Grande école" = "Ecole d'Ingénieur"

    
  ))

# %%
modele_lda_simple <- lda(filiere ~ ., data = df_lda_simple)
modele_lda_simple
# Out:
# Warning message in lda.default(x, grouping, ...):
# "le groupe Autre formation est vide"
# Warning message in lda.default(x, grouping, ...):
# "les variables sont colinéaires"
# Call:
# lda(filiere ~ ., data = df_lda_simple)
#
# Prior probabilities of groups:
#      BUT/BTS Grande école        Santé      Licence
#    0.5157192    0.1469004    0.0919836    0.2453968
#
# Group means:
#              Capacité.de.l.établissement.par.formation
# BUT/BTS                                       36.79155
# Grande école                                  52.52874
# Santé                                         68.59790
# Licence                                      101.27457
#              Effectif.total.admis.2phases Effectif.total.candidats.2phases
# BUT/BTS                          28.19255                         562.4994
# Grande école                     42.98358                        1448.3103
# Santé                            67.73776                        2677.5743
# Licence                          92.44528                        1088.2231
#              Pourcentage.boursiers.candidats Pourcentage.boursiers.admis
# BUT/BTS                             25.06506                    26.80695
# Grande école                        10.31493                    10.75963
# Santé                               21.09249                    22.72779
# Licence                             20.26498                    22.59379
#              pct_filles_admises pct_garcons_admis pression_candidature
# BUT/BTS               0.4345022         0.5654978             15.91194
# Grande école          0.3815807         0.6184193             32.43983
# Santé                 0.7280408         0.2719592             53.33301
# Licence               0.6301511         0.3698489             14.75862
#              taux_admission taux_remplissage taux_acces_num part_mention_ab
# BUT/BTS          0.09058891        0.8259447      0.5757764       0.3591446
# Grande école     0.05478752        0.7527434      0.6023645       0.2726735
# Santé            0.04375933        0.9752614      0.4658304       0.3442463
# Licence          0.10947427        0.8717824      0.6898657       0.3128011
#              part_mention_b part_mention_tb part_mention_tb_fel
# BUT/BTS           0.1654459      0.03719664         0.002238626
# Grande école      0.3242836      0.19878705         0.027726798
# Santé             0.2614183      0.10443939         0.012638522
# Licence           0.2228250      0.09217691         0.009925914
#              part_mention_haute score_mention
# BUT/BTS              0.03946526     0.8036028
# Grande école         0.22670597     1.5838121
# Santé                0.11709266     1.2275234
# Licence              0.10214374     1.0651662
#              X..d.admis.néo.bacheliers.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies.
# BUT/BTS                                                                                    83.30870
# Grande école                                                                               64.80952
# Santé                                                                                      80.96241
# Licence                                                                                    71.25098
#              X..d.admis.néo.bacheliers.généraux
# BUT/BTS                                22.69208
# Grande école                           79.36508
# Santé                                  75.62587
# Licence                                81.67202
#              X..d.admis.néo.bacheliers.technologiques
# BUT/BTS                                      36.30309
# Grande école                                 13.82047
# Santé                                        15.55245
# Licence                                      10.81815
#              X..d.admis.néo.bacheliers.professionnels log_candidats log_admis
# BUT/BTS                                     40.085750      5.698516  3.112469
# Grande école                                 1.119321      6.481375  3.196687
# Santé                                        8.379371      7.255830  3.766141
# Licence                                      6.287353      6.300484  3.890516
#              log_capacite
# BUT/BTS          3.347703
# Grande école     3.602997
# Santé            3.798622
# Licence          4.102106
#
# Coefficients of linear discriminants:
#                                                                                                  LD1
# Capacité.de.l.établissement.par.formation                                              -1.257568e-03
# Effectif.total.admis.2phases                                                            3.241666e-03
# Effectif.total.candidats.2phases                                                        9.401708e-06
# Pourcentage.boursiers.candidats                                                         7.104151e-03
# Pourcentage.boursiers.admis                                                             7.245279e-03
# pct_filles_admises                                                                      2.364204e-01
# pct_garcons_admis                                                                      -2.364204e-01
# pression_candidature                                                                   -1.912509e-04
# taux_admission                                                                          2.044212e+00
# taux_remplissage                                                                        4.887144e-01
# taux_acces_num                                                                          1.871604e+00
# part_mention_ab                                                                         1.059229e+01
# part_mention_b                                                                          2.241156e+01
# part_mention_tb                                                                         1.743438e+01
# part_mention_tb_fel                                                                     2.782383e+01
# part_mention_haute                                                                      1.619390e+01
# score_mention                                                                          -1.067142e+01
# X..d.admis.néo.bacheliers.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies. -2.882739e-03
# X..d.admis.néo.bacheliers.généraux                                                      9.607133e-02
# X..d.admis.néo.bacheliers.technologiques                                                6.165550e-02
# X..d.admis.néo.bacheliers.professionnels                                                5.292883e-02
# log_candidats                                                                           2.456068e-01
# log_admis                                                                              -5.912849e-01
# log_capacite                                                                            3.771740e-01
#                                                                                                  LD2
# Capacité.de.l.établissement.par.formation                                              -1.282769e-03
# Effectif.total.admis.2phases                                                            3.090094e-03
# Effectif.total.candidats.2phases                                                       -1.816244e-05
# Pourcentage.boursiers.candidats                                                         3.086823e-02
# Pourcentage.boursiers.admis                                                             4.279895e-03
# pct_filles_admises                                                                      9.145494e-01
# pct_garcons_admis                                                                      -9.145494e-01
# pression_candidature                                                                    1.137475e-02
# taux_admission                                                                         -5.806580e+00
# taux_remplissage                                                                        1.803489e+00
# taux_acces_num                                                                         -6.604915e-01
# part_mention_ab                                                                        -4.912385e+00
# part_mention_b                                                                         -1.014253e+01
# part_mention_tb                                                                        -7.972796e+00
# part_mention_tb_fel                                                                    -1.269163e+01
# part_mention_haute                                                                     -7.352934e+00
# score_mention                                                                           4.071007e+00
# X..d.admis.néo.bacheliers.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies. -3.716743e-03
# X..d.admis.néo.bacheliers.généraux                                                     -1.565127e-02
# X..d.admis.néo.bacheliers.technologiques                                               -3.299661e-02
# X..d.admis.néo.bacheliers.professionnels                                               -1.733374e-02
# log_candidats                                                                          -1.243910e+00
# log_admis                                                                               4.834904e-01
# log_capacite                                                                            9.331163e-01
#                                                                                                  LD3
# Capacité.de.l.établissement.par.formation                                              -0.0020200646
# Effectif.total.admis.2phases                                                            0.0063515971
# Effectif.total.candidats.2phases                                                       -0.0005330967
# Pourcentage.boursiers.candidats                                                         0.0087991278
# Pourcentage.boursiers.admis                                                             0.0023370426
# pct_filles_admises                                                                     -0.7156906365
# pct_garcons_admis                                                                       0.7156906365
# pression_candidature                                                                   -0.0030490935
# taux_admission                                                                          2.3390509292
# taux_remplissage                                                                       -1.0578048860
# taux_acces_num                                                                         -0.3876286424
# part_mention_ab                                                                        -3.1306465776
# part_mention_b                                                                         -5.2749256465
# part_mention_tb                                                                        -3.4965215374
# part_mention_tb_fel                                                                    -6.9068828568
# part_mention_haute                                                                     -3.4069994277
# score_mention                                                                           2.8367586969
# X..d.admis.néo.bacheliers.issus.de.la.même.académie..Paris.Créteil.Versailles.réunies. -0.0146663405
# X..d.admis.néo.bacheliers.généraux                                                     -0.0138022916
# X..d.admis.néo.bacheliers.technologiques                                               -0.0130118529
# X..d.admis.néo.bacheliers.professionnels                                               -0.0161662247
# log_candidats                                                                          -0.1957983168
# log_admis                                                                               0.0220438008
# log_capacite                                                                            0.5823312570
#
# Proportion of trace:
#    LD1    LD2    LD3
# 0.7413 0.1718 0.0869

# %%
prop_variance <- modele_lda_simple$svd^2 / sum(modele_lda_simple$svd^2)
round(prop_variance * 100, 1)
# Out:
# [1] 74.1 17.2  8.7

# %%
predictions_simple <- predict(modele_lda_simple)

df_plot_simple <- data.frame(
  LD1 = predictions_simple$x[, 1],
  LD2 = predictions_simple$x[, 2],
  filiere = df_lda_simple$filiere
)

head(df_plot_simple)
# Out:
#   LD1         LD2         filiere
# 1 -0.45190518  1.48419191 Licence
# 2 -0.45849311  0.02569147 Santé
# 3  1.96674467  0.24323973 Santé
# 4  2.28226626 -0.66266382 Santé
# 5  0.08829456  0.82903046 Licence
# 6  1.27892227  1.48690094 Santé

# %%
ggplot(df_plot_simple, aes(x = LD1, y = LD2, color = filiere)) +
  geom_point(alpha = 0.4, size = 1.5) +
  stat_ellipse(aes(group = filiere), type = "norm", linetype = "dashed") +
  labs(
    title = "LDA — Séparation des filières Parcoursup par thème",
    x = paste0("LD1 (", round(prop_variance[1] * 100, 1), "%)"),
    y = paste0("LD2 (", round(prop_variance[2] * 100, 1), "%)")
  ) +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# Commentaire : ça donne pas grand chose...
