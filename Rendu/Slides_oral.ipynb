# %% [markdown]
# ### Slide 1 Introduction --Romain

# %% [markdown]
# accroche augustin prq il est nul et pas pris à l'insa ==> ça nous a poussé à nous intéresser aux stats de parcoursup

# %% [markdown]
# ### Slide 2 : Présentaion jeu de données --Romain

# %% [markdown]
# - source data.gouv
# - jeu de données: 14000 individus, 130 variables
# - individus= formations parcoursup
# - variables: filière, nombre de candidats, admis, part de filles....

# %% [markdown]
# angle de l'analyse:
# types de filières, régions, filles, boursiers, taux d'accès...

# %% [markdown]
# ### Slide 3 : Présentaion jeu de données -- Augustin

# %% [markdown]
# - étape de nettoyage: beaucoup de variables inutiles pour l'analyse, trop précises, redondantes, ou trop de NaN.
# - extraction de quelques features utiles: (ex: pression candidature, score mention...)

# %% [markdown]
# ### Slides 4-5 : analyse uni -- Romain

# %% [markdown]
# - quelques histogrammes de var quanti + explication de nécessité de retransformation ou non
# - quelques diagrammes barre pour var quali
# - présentation de quelques stats de base (moyennes de boursiers, filles...)

# %% [markdown]
# ### présentation carte visu -- Coco

# %% [markdown]
# - présentation de la carte interactive, coloriée avec taux d'accès

# %% [markdown]
# ### Slide 6 : analyse bidim -- Romain

# %% [markdown]
# - quanti-quanti: grande matrice de corrélation, peu de résultats obtenus

# %% [markdown]
# ### Slide 7 : analyse bidim -- Gus

# %% [markdown]
# - quali-quali: mosaic plots ancrage local-région, genre-boursier...

# %% [markdown]
# ### Slide 8 : analyse bidim --Coco

# %% [markdown]
# - quali-quanti: taux d'accès-fillière, filles-fillières, filles-régions, boursiers-privé...

# %% [markdown]
# ### Slide 9-10 : ACP --Coco

# %% [markdown]
# - explication rapide méthode, screeplot: peu de réduction de dimension possible
# - var_viz, explication des corrélations
# - ind_viz + habillages multiples, identification de clusters

# %% [markdown]
# ### Slide 11-12 : clustering acp -- Romain
#
# - présente les 2-3 méthodes utilisées, résultats + interprétation et confirmation des hypothèses faites sur la visualisation, comparaison des méthodes

# %% [markdown]
# ### CA/MCA --Gus

# %% [markdown]
# présentation rapide de la méthode et des résultats obtenus

# %% [markdown]
# ### Slide 11 :  Clustering ACM
# - pas besoin de reprendre l'explication des méthodes, on montre juste les résultats visuels + comparaison

# %% [markdown]
# ### Ouverture autres clusterings

# %% [markdown]
# Mention des autres méthodes testées (LDA, MFA, DBSCAN, SBM, graph clustering...) mais qui étaient pas concluantes.

# %% [markdown]
# ### Conclusion + synthese

# %% [markdown]
# - présentation des principaux résultats obtenus

# %% [markdown]
# ### Slide questions
